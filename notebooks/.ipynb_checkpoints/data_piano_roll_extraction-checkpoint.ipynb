# %% [markdown]
# # Final Project - Piano Roll Extraction
# - Course: AAI-511-Neural Networks
# - Institution: University of San Diego
# - Professor: Kahila Mokhtari Jadid
# - Group 4 Members:
#     * Lucas Young
#     * Titouan Margret
#     * Juan Pablo Triana Martinez
#
# This notebook has the intention to go through the `final_proj_data` folder inside `data` folder, and do the following:
# 1. Repeat all the steps done in `eda_midi.ipynb`, with a little twist this time.
# 2. We would readapt one of the classes to also give us the label for each song!
# 3. Additionally, we are gonna take a look into `pad_sequence` function from `torch.rnn` to use it for CNN-LSTM approaches.

# %%
#Import necessary modules
import os
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# %%
# Data path file
curr_path = Path.cwd()
data_path = curr_path.parent / "data" / "final_proj_data"

if data_path.exists():
    print("Valid path to use to retreive midi files information")
else:
    print("Run appropiate code to retrieve the dataset")
# Out:
# Valid path to use to retreive midi files information

# %%
from mido import MidiFile
from tqdm import tqdm
from typing import List, Tuple

class MidiPreprocesser:
    '''
    Class that would process all files found
    inside the final_proj_data folder and retrieve
    all the midi info for each of the files

    Args:
        data_path : Path from pathlib where data folder is located.

    Returns:
        midi_object: will see :)

    Example:
        midipreprocesser = MidiPreprocesser(data_path = set_path)
        midiobj, labels_composer = midipreprocesser.get_midi_info()
    '''

    def __init__(self, data_path:Path):
        self.data_path = data_path
    
    def _convert_composers_class_idx(self, labels: List[str]) -> List[int]:
        class_indices = []
        for composer in labels:
            if composer == "Bach":
                class_indices.append(1)
            elif composer == "Beethoven":
                class_indices.append(2)
            elif composer == "Chopin":
                class_indices.append(3)
            elif composer == "Mozart":
                class_indices.append(4)
            else:
                class_indices.append(0)
        return class_indices

    def get_midi_info(self) -> Tuple[List[Tuple[str, MidiFile]], List[int]]:
        midis = []
        labels_composer = []
        for root, dirs, files in tqdm(self.data_path.walk(), desc="Reading composers.."):
            count = 0
            for file in tqdm(files, desc=f"Reading_{root.stem} files...", total=len(files)):
                if file.endswith(".mid"):
                    try:
                        midis.append((root.stem + "_" + str(count), MidiFile(Path(root) / file)))
                        labels_composer.append(root.name)
                        count += 1
                    except:
                        print(f"{file} cannot be read, is skipped")
                        continue
        labels_composer = self._convert_composers_class_idx(labels_composer)
        return midis, labels_composer

# %%
midipreprocesser = MidiPreprocesser(data_path = data_path)
midiobj, labels_composer = midipreprocesser.get_midi_info()
# Out:
# Reading_final_proj_data files...: 0it [00:00, ?it/s]
# Reading_Bach files...: 100%|██████████| 136/136 [00:05<00:00, 24.55it/s]
# Reading composers..: 2it [00:05,  2.78s/it]
# Anhang 14-3.mid cannot be read, is skipped
# Reading_Beethoven files...: 100%|██████████| 212/212 [00:19<00:00, 10.71it/s]
# Reading_Chopin files...: 100%|██████████| 925/925 [00:25<00:00, 36.53it/s]
# Reading composers..: 4it [00:50, 15.64s/it]
# K281 Piano Sonata n03 3mov.mid cannot be read, is skipped
# Reading_Mozart files...: 100%|██████████| 257/257 [00:16<00:00, 15.72it/s]
# Reading composers..: 5it [01:07, 13.41s/it]

# %% [markdown]
# ### Labels distribution.
# Now that we have the array of labels for each composer, the next step is to do the following:
# 1. Plot the histogram of the labels to see their distribution, in order to handle unbalanced data

# %%
fig = plt.figure(figsize=(16, 8))
fig.suptitle("Label distribution: 1-> Bach, 2-> Bethoven, 3-> Chopin, 4-> Mozart")
ax1 = fig.add_subplot(1, 1, 1)
ax1.hist(labels_composer)
plt.show()

# %% [markdown]
# ### UNBALANCED DATASET
# Well! This is surprising, we have now an unbalanced label towards `Chopin` music, this is gonna be key when we are dealing with data augmentation techniques,
# specially, these are the following issues:
# - After converting the files to `np.ndarrays` and store them in a `List`, we are gonna use `pad_sequences` to pad them properly
# - After this, we would create a **DataAugmentation** pipeline to set a certain number of images, we would like to have:
#     - 300 Images per composer, meaning we would need to oversample `Bach`,  `Bethoven`, and `Mozart`, and undersample `Chopin`
# - Finally, create a customized `Dataset` from `torch.utils.data`.

# %%
from mido import MidiFile
from typing import Union, Tuple
import numpy as np

class MidiToNumpy:
    '''
    Class that would process one Midifile
    object, and do the following:
        - Set the midi ticks per beat
        - Set the fs to discretize Midi information -> Discrete symbolic numpy array
        - Iterate across all tracks and find events of the following:
            * set_tempo
            * note_on
            * note_off
        - create a numpy array of zeroes of size (128, T) 

        Args:
            file: Midifile containing all tracks to use.
            tempo: Integer representing default tempo time for a midi file in microseconds/beat.
            values can be 500,000 or 1000,000
            fs: Integer representing discretize frequency sample time for evets, default = 10
        
        Returns:
            np_piano: np.ndarray of size (128, T) representation
            of the midi file

        Example:
            midi_np_processor = MidiToNumpy(file = midi_file,
                                default_tempo = 500000, fs = 10)
            np_midi = midi_np_processor.get_np_array()
    '''

    def __init__(self, file:MidiFile, default_tempo:int = 500000, fs:int = 10) -> None:
        self.file = file
        self.ticks_per_beat = file.ticks_per_beat
        self.tempo = default_tempo
        self.fs = fs

    def _calculate_seconds(self, ticks:int) -> Union[float, int]:
        return (ticks / self.ticks_per_beat) * (self.tempo / 1_000_000)

    def _get_np_array_info(self) -> Tuple[float, float, int, int]:
        # List to hold note start and end info
        notes = []

        for track in self.file.tracks:
            time_ticks = 0
            ongoing_notes = {}
            for msg in track:
                time_ticks += msg.time
                if msg.type == 'set_tempo':
                    self.tempo = msg.tempo
                elif msg.type == 'note_on' and msg.velocity > 0:
                    # Start note
                    ongoing_notes[msg.note] = (time_ticks, msg.note, msg.velocity)
                elif (msg.type == 'note_off') or (msg.type == 'note_on' and msg.velocity == 0):
                    # End note
                    if msg.note in ongoing_notes:
                        start_time_ticks, note, note_velocity = ongoing_notes.pop(msg.note)
                        
                        #Convert tick times to seconds
                        start_time = self._calculate_seconds(ticks=start_time_ticks)
                        time = self._calculate_seconds(ticks=time_ticks)
                        notes.append((start_time, time, note, note_velocity))
        return notes

    def get_np_array(self) -> Tuple[np.ndarray[int, float], str]:
        notes_info = self._get_np_array_info()

        #Let's get end time to create he np.ndarray
        _ , final_time , _ , _ = notes_info[-1]
        np_array = np.zeros(shape = (128, int(np.floor(final_time)*self.fs)), dtype=np.float32)

        for start_time, time, note, note_velocity in tqdm(notes_info, desc=f"Creating Piano roll: {self.file.filename.stem}", total=len(notes_info)):
            start_time_clipped = int(np.round(start_time*self.fs))
            time_clipped = int(np.round(time*self.fs))
            np_array[note, start_time_clipped:time_clipped] = note_velocity

        return np_array, self.file.filename.stem

# %%
def obtain_piano_rolls(midiobject: List[Tuple[str, MidiFile]]) -> Tuple [List[np.ndarray], List[str], List[str]]:
    '''
    Args:
        midiobject: list containing tuples of song names and related MidiFile
    
    Returns:
        list_np_arrays: list of np_arrays for each of the piano rolls.
        list_composer_names: list containing composer names.
        list_file_names: List containing song names.
    
    Example:
        list_np_arrays, list_composer_names = obtain_piano_rolls(midiobject = midiobj)
    '''

    list_np_arrays = []
    list_comp_names = []
    list_song_names = []
    for name , midifile in midiobject:
        # With customized class
        midi_np_processor = MidiToNumpy(file = midifile,
                            default_tempo = 500000, fs = 10)
        np_array, file_name = midi_np_processor.get_np_array()
        list_song_names.append(file_name)
        list_np_arrays.append(np_array)
        list_comp_names.append(name)

    return list_np_arrays, list_comp_names, list_song_names

# %%
list_np_arrays, list_composer_names, list_song_names = obtain_piano_rolls(midiobject = midiobj)
# Out:
# Creating Piano roll: (2542)Prelude opus.28, No.16 in B flat minor: 100%|██████████| 1195/1195 [00:00<00:00, 214885.03it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.10: 100%|██████████| 1742/1742 [00:00<00:00, 192732.20it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.11: 100%|██████████| 669/669 [00:00<00:00, 226362.49it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.12: 100%|██████████| 682/682 [00:00<00:00, 341839.79it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.13: 100%|██████████| 1062/1062 [00:00<00:00, 149887.30it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.14: 100%|██████████| 602/602 [00:00<00:00, 201192.91it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.15: 100%|██████████| 1580/1580 [00:00<00:00, 189472.79it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.16: 100%|██████████| 1021/1021 [00:00<00:00, 194089.21it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.17: 100%|██████████| 1698/1698 [00:00<00:00, 232933.06it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.18: 100%|██████████| 1396/1396 [00:00<00:00, 174206.31it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.19: 100%|██████████| 358/358 [00:00<00:00, 298461.70it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.2: 100%|██████████| 778/778 [00:00<00:00, 192847.26it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.3: 100%|██████████| 907/907 [00:00<00:00, 302595.75it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.4: 100%|██████████| 1768/1768 [00:00<00:00, 214383.62it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.5: 100%|██████████| 394/394 [00:00<00:00, 98536.51it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.6: 100%|██████████| 980/980 [00:00<00:00, 196023.55it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.7: 100%|██████████| 1050/1050 [00:00<00:00, 264188.31it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.8: 100%|██████████| 1043/1043 [00:00<00:00, 208545.51it/s]
# Creating Piano roll: 19 Polish Songs, for Solo Voice and Piano accomplements, No.9: 100%|██████████| 493/493 [00:00<00:00, 122863.45it/s]
# Creating Piano roll: 2 Polonaises op26 n1: 100%|██████████| 3581/3581 [00:00<00:00, 230022.86it/s]
# Creating Piano roll: Ballad op32: 100%|██████████| 5028/5028 [00:00<00:00, 227281.12it/s]
# Creating Piano roll: Ballad op53: 100%|██████████| 6051/6051 [00:00<00:00, 231943.61it/s]
# Creating Piano roll: Ballade No.2 in F Major: 100%|██████████| 4235/4235 [00:00<00:00, 222829.80it/s]
# Creating Piano roll: Barcarolle in F sharp Major: 100%|██████████| 4793/4793 [00:00<00:00, 237240.66it/s]
# Creating Piano roll: Ecossaise No.2 in G: 100%|██████████| 438/438 [00:00<00:00, 68911.26it/s]
# Creating Piano roll: Etude No.1: 100%|██████████| 1332/1332 [00:00<00:00, 182760.74it/s]
# Creating Piano roll: Etude No.2 in A Minor: 100%|██████████| 1457/1457 [00:00<00:00, 138923.39it/s]
# Creating Piano roll: Etude No.7 in C Major Opus.10, No.7: 100%|██████████| 1785/1785 [00:00<00:00, 144263.30it/s]
# Creating Piano roll: Etude Op 25, No.1: 100%|██████████| 3646/3646 [00:00<00:00, 218822.81it/s]
# Creating Piano roll: Etude op. 10-5 Black keys: 100%|██████████| 1628/1628 [00:00<00:00, 267232.58it/s]
# Creating Piano roll: Etude Op.10 No.11: 100%|██████████| 1963/1963 [00:00<00:00, 226479.03it/s]
# Creating Piano roll: Etude op10 n01: 100%|██████████| 1322/1322 [00:00<00:00, 261340.90it/s]
# Creating Piano roll: Etude op10 n02: 100%|██████████| 1457/1457 [00:00<00:00, 225751.79it/s]
# Creating Piano roll: Etude op10 n03: 100%|██████████| 1844/1844 [00:00<00:00, 223676.81it/s]
# Creating Piano roll: Etude op10 n04 Drchew: 100%|██████████| 2204/2204 [00:00<00:00, 183636.19it/s]
# Creating Piano roll: Etude op10 n05 ''Black Key'': 100%|██████████| 1630/1630 [00:00<00:00, 203746.55it/s]
# Creating Piano roll: Etude op10 n06: 100%|██████████| 948/948 [00:00<00:00, 235584.80it/s]
# Creating Piano roll: Etude op10 n07: 100%|██████████| 1785/1785 [00:00<00:00, 223087.98it/s]
# Creating Piano roll: Etude op10 n08: 100%|██████████| 2303/2303 [00:00<00:00, 241613.90it/s]
# Creating Piano roll: Etude op10 n09: 100%|██████████| 1234/1234 [00:00<00:00, 270614.41it/s]
# Creating Piano roll: Etude op10 n10: 100%|██████████| 2231/2231 [00:00<00:00, 216759.14it/s]
# Creating Piano roll: Etude op10 n11: 100%|██████████| 1984/1984 [00:00<00:00, 143131.10it/s]
# Creating Piano roll: Etude op10 n12 ''Revolutionary'': 100%|██████████| 2086/2086 [00:00<00:00, 208113.94it/s]
# Creating Piano roll: Etude op25 n01 ''Harp Etude'': 100%|██████████| 2393/2393 [00:00<00:00, 212427.13it/s]
# Creating Piano roll: Etude op25 n02: 100%|██████████| 1203/1203 [00:00<00:00, 240594.49it/s]
# Creating Piano roll: Etude op25 n03: 100%|██████████| 1693/1693 [00:00<00:00, 221593.28it/s]
# Creating Piano roll: Etude op25 n04: 100%|██████████| 1504/1504 [00:00<00:00, 214858.08it/s]
# Creating Piano roll: Etude op25 n05: 100%|██████████| 2155/2155 [00:00<00:00, 195876.59it/s]
# Creating Piano roll: Etude op25 n06: 100%|██████████| 2508/2508 [00:00<00:00, 208596.53it/s]
# Creating Piano roll: Etude op25 n07: 100%|██████████| 1631/1631 [00:00<00:00, 119298.08it/s]
# Creating Piano roll: Etude op25 n08: 100%|██████████| 1549/1549 [00:00<00:00, 164914.63it/s]
# Creating Piano roll: Etude op25 n09: 100%|██████████| 1049/1049 [00:00<00:00, 112286.26it/s]
# Creating Piano roll: Etude op25 n10: 100%|██████████| 3357/3357 [00:00<00:00, 212125.86it/s]
# Creating Piano roll: Etude op25 n11 ''Winter Wind'': 100%|██████████| 3159/3159 [00:00<00:00, 224196.79it/s]
# Creating Piano roll: Etude op25 n12 ''The Ocean'': 100%|██████████| 2634/2634 [00:00<00:00, 78652.16it/s]
# Creating Piano roll: Fantasie Impromptu op66: 100%|██████████| 3046/3046 [00:00<00:00, 135219.94it/s]
# Creating Piano roll: Finale to B Minor Paino Sonata: 100%|██████████| 4851/4851 [00:00<00:00, 188427.30it/s]
# Creating Piano roll: Grande Waltz op18: 100%|██████████| 4408/4408 [00:00<00:00, 219466.21it/s]
# Creating Piano roll: Imprompt Fantastique: 100%|██████████| 3049/3049 [00:00<00:00, 224397.84it/s]
# Creating Piano roll: Impromptu n3 op51: 100%|██████████| 2428/2428 [00:00<00:00, 210378.05it/s]
# Creating Piano roll: Mazurka op30 n2 Drchew: 100%|██████████| 787/787 [00:00<00:00, 196670.47it/s]
# Creating Piano roll: Mazurka op33 n2 Drchew: 100%|██████████| 1679/1679 [00:00<00:00, 199079.45it/s]
# Creating Piano roll: Mazurka op67 n3 Drchew: 100%|██████████| 708/708 [00:00<00:00, 234766.96it/s]
# Creating Piano roll: Mazurka op68 n2 Drchew: 100%|██████████| 773/773 [00:00<00:00, 180593.61it/s]
# Creating Piano roll: Mazurka op7 n1: 100%|██████████| 1229/1229 [00:00<00:00, 131563.76it/s]
# Creating Piano roll: Mazurka op7 n2: 100%|██████████| 1207/1207 [00:00<00:00, 227314.67it/s]
# Creating Piano roll: Nocturne No.1, Opus.62: 100%|██████████| 2044/2044 [00:00<00:00, 185875.97it/s]
# Creating Piano roll: Nocturne No.15 in F Minor Opus.55 -1: 100%|██████████| 1456/1456 [00:00<00:00, 85600.44it/s]
# Creating Piano roll: Nocturne No.18 in E Major Op62: 100%|██████████| 1787/1787 [00:00<00:00, 197341.34it/s]
# Creating Piano roll: Nocturne op09 n2: 100%|██████████| 1298/1298 [00:00<00:00, 162319.81it/s]
# Creating Piano roll: Nocturne op09 n3: 100%|██████████| 2430/2430 [00:00<00:00, 202297.62it/s]
# Creating Piano roll: Nocturne op15 n2: 100%|██████████| 1151/1151 [00:00<00:00, 181626.93it/s]
# Creating Piano roll: Nocturne op15 n3: 100%|██████████| 1094/1094 [00:00<00:00, 209887.87it/s]
# Creating Piano roll: Nocturne op27 n1: 100%|██████████| 1633/1633 [00:00<00:00, 56440.65it/s]
# Creating Piano roll: Nocturne op27 n2: 100%|██████████| 1830/1830 [00:00<00:00, 110683.61it/s]
# Creating Piano roll: Nocturne op32 n1: 100%|██████████| 1281/1281 [00:00<00:00, 171133.37it/s]
# Creating Piano roll: Nocturne op32 n2: 100%|██████████| 2405/2405 [00:00<00:00, 198882.12it/s]
# Creating Piano roll: Nocturne op33 n2: 100%|██████████| 1933/1933 [00:00<00:00, 211769.35it/s]
# Creating Piano roll: Nocturne op33 n4: 100%|██████████| 2165/2165 [00:00<00:00, 217027.99it/s]
# Creating Piano roll: Nocturne op37 01: 100%|██████████| 1546/1546 [00:00<00:00, 244675.65it/s]
# Creating Piano roll: Nocturne op37 n2: 100%|██████████| 1876/1876 [00:00<00:00, 224308.40it/s]
# Creating Piano roll: Nocturne op48 n1: 100%|██████████| 3195/3195 [00:00<00:00, 215668.88it/s]
# Creating Piano roll: Nocturne op48 n2: 100%|██████████| 2083/2083 [00:00<00:00, 219593.20it/s]
# Creating Piano roll: Nocturne op55 n1: 100%|██████████| 1456/1456 [00:00<00:00, 207640.22it/s]
# Creating Piano roll: Nocturne op55 n2: 100%|██████████| 1475/1475 [00:00<00:00, 209850.36it/s]
# Creating Piano roll: Nocturne op62 n2: 100%|██████████| 1787/1787 [00:00<00:00, 172482.37it/s]
# Creating Piano roll: Nocturne op72 n1: 100%|██████████| 1180/1180 [00:00<00:00, 236140.98it/s]
# Creating Piano roll: Op.53 'Polonaise in A flat' Heroic: 100%|██████████| 6166/6166 [00:00<00:00, 227510.94it/s]
# Creating Piano roll: Piano Concerto n1 op11 1mov: 100%|██████████| 19929/19929 [00:00<00:00, 222586.91it/s]
# Creating Piano roll: Piano Concerto n1 op11 2mov: 100%|██████████| 4116/4116 [00:00<00:00, 220541.34it/s]
# Creating Piano roll: Piano Concerto n1 op11 3mov: 100%|██████████| 14052/14052 [00:00<00:00, 171611.81it/s]
# Creating Piano roll: Piano Concerto n2 1mov: 100%|██████████| 13633/13633 [00:00<00:00, 227686.45it/s]
# Creating Piano roll: Piano Concerto n2 2mov: 100%|██████████| 8849/8849 [00:00<00:00, 227401.87it/s]
# Creating Piano roll: Piano Concerto n2 3mov: 100%|██████████| 10107/10107 [00:00<00:00, 224641.28it/s]
# Creating Piano roll: Polonaise Opus.40, No.1 (Military): 100%|██████████| 5385/5385 [00:00<00:00, 237813.39it/s]
# Creating Piano roll: Prelude n01 op28 ''Reunion'': 100%|██████████| 327/327 [00:00<00:00, 164670.12it/s]
# Creating Piano roll: Prelude n02 op28 ''Presentiment of Death'': 100%|██████████| 342/342 [00:00<00:00, 171053.18it/s]
# Creating Piano roll: Prelude n03 op28 ''Thou Art So Like A Flower'': 100%|██████████| 662/662 [00:00<00:00, 79493.52it/s]
# Creating Piano roll: Prelude n04 op28 ''Suffocation'': 100%|██████████| 601/601 [00:00<00:00, 120202.98it/s]
# Creating Piano roll: Prelude n05 op28 ''Uncertainty'': 100%|██████████| 460/460 [00:00<00:00, 63210.69it/s]
# Creating Piano roll: Prelude n06 op28 ''Tolling Bells'': 100%|██████████| 405/405 [00:00<00:00, 101269.41it/s]
# Creating Piano roll: Prelude n07 op28 ''The Polish Dance'': 100%|██████████| 164/164 [00:00<00:00, 164246.86it/s]
# Creating Piano roll: Prelude n08 op28 ''Desparation'': 100%|██████████| 1560/1560 [00:00<00:00, 136190.04it/s]
# Creating Piano roll: Prelude n09 op28 ''Vision'': 100%|██████████| 413/413 [00:00<00:00, 139832.71it/s]
# Creating Piano roll: Prelude n10 op28 ''The Night Moth'': 100%|██████████| 320/320 [00:00<00:00, 106844.23it/s]
# Creating Piano roll: Prelude n11 op28 ''Dragonfly'': 100%|██████████| 321/321 [00:00<00:00, 147176.61it/s]
# Creating Piano roll: Prelude n12 op28 ''Duel'': 100%|██████████| 1225/1225 [00:00<00:00, 195035.77it/s]
# Creating Piano roll: Prelude n13 op28 ''Loss'': 100%|██████████| 903/903 [00:00<00:00, 225887.55it/s]
# Creating Piano roll: Prelude n14 op28 ''Fear'': 100%|██████████| 434/434 [00:00<00:00, 216912.29it/s]
# Creating Piano roll: Prelude n15 op28 ''Raindrop'': 100%|██████████| 1515/1515 [00:00<00:00, 244286.12it/s]
# Creating Piano roll: Prelude n16 op28 ''Hades'': 100%|██████████| 1198/1198 [00:00<00:00, 163956.54it/s]
# Creating Piano roll: Prelude n17 op28 ''Scene On the Place of Notre Dame: 100%|██████████| 2495/2495 [00:00<00:00, 171180.68it/s]
# Creating Piano roll: Prelude n18 op28 ''Suicide'': 100%|██████████| 573/573 [00:00<00:00, 136522.16it/s]
# Creating Piano roll: Prelude n19 op28: 100%|██████████| 1237/1237 [00:00<00:00, 141696.36it/s]
# Creating Piano roll: Prelude n20 op28 ''Funeral March'': 100%|██████████| 286/286 [00:00<00:00, 142687.16it/s]
# Creating Piano roll: Prelude n21 op28 ''Sunday'': 100%|██████████| 870/870 [00:00<00:00, 173483.15it/s]
# Creating Piano roll: Prelude n22 op28 ''Impatience'': 100%|██████████| 631/631 [00:00<00:00, 105128.33it/s]
# Creating Piano roll: Prelude n23 op28 ''A Pleasure Boat'': 100%|██████████| 526/526 [00:00<00:00, 131486.02it/s]
# Creating Piano roll: Prelude n24 op28 ''The Storm'': 100%|██████████| 1371/1371 [00:00<00:00, 228652.86it/s]
# Creating Piano roll: Prelude op.28-15 Raindrop: 100%|██████████| 1512/1512 [00:00<00:00, 188901.10it/s]
# Creating Piano roll: Revolutionary: 100%|██████████| 2101/2101 [00:00<00:00, 202152.52it/s]
# Creating Piano roll: Scherzo n1 op20: 100%|██████████| 4781/4781 [00:00<00:00, 116342.16it/s]
# Creating Piano roll: Scherzo No.2, Opus.31: 100%|██████████| 5944/5944 [00:00<00:00, 206938.73it/s]
# Creating Piano roll: Scherzo op31: 100%|██████████| 5975/5975 [00:00<00:00, 236696.64it/s]
# Creating Piano roll: Sonata No.3 1st Mov Allegro: 100%|██████████| 4860/4860 [00:00<00:00, 220518.81it/s]
# Creating Piano roll: Sonata No.3, 2nd Mov, Scherzo: 100%|██████████| 1435/1435 [00:00<00:00, 238719.16it/s]
# Creating Piano roll: Sonata op35 n1 : 100%|██████████| 5604/5604 [00:00<00:00, 200050.04it/s]
# Creating Piano roll: Sonata op35 n2 : 100%|██████████| 4775/4775 [00:00<00:00, 230038.04it/s]
# Creating Piano roll: Sonata op35 n3 : 100%|██████████| 2323/2323 [00:00<00:00, 141888.89it/s]
# Creating Piano roll: Sonata op35 n4 : 100%|██████████| 1760/1760 [00:00<00:00, 218991.22it/s]
# Creating Piano roll: Tarantella: 100%|██████████| 3221/3221 [00:00<00:00, 197172.32it/s]
# Creating Piano roll: Trois Nouvelles Etudes (Op.posth.): 100%|██████████| 3110/3110 [00:00<00:00, 204487.94it/s]
# Creating Piano roll: Waltz in Ab (Op.posth., Brown21): 100%|██████████| 2158/2158 [00:00<00:00, 148156.22it/s]
# Creating Piano roll: Waltz op64 n1: 100%|██████████| 1436/1436 [00:00<00:00, 212594.70it/s]
# Creating Piano roll: Waltz op70 n2: 100%|██████████| 1371/1371 [00:00<00:00, 195958.11it/s]
# Creating Piano roll: Winter wind etude: 100%|██████████| 3187/3187 [00:00<00:00, 187457.88it/s]
# Creating Piano roll: 32 Variations on a theme: 100%|██████████| 7318/7318 [00:00<00:00, 212413.18it/s]
# Creating Piano roll: Andante in F Major: 100%|██████████| 4278/4278 [00:00<00:00, 246286.91it/s]
# Creating Piano roll: Anh06 Rondo: 100%|██████████| 4438/4438 [00:00<00:00, 186900.16it/s]
# Creating Piano roll: Anh08Nb1 Gavotte 4 hands: 100%|██████████| 1570/1570 [00:00<00:00, 220361.32it/s]
# Creating Piano roll: Bagatella Fur Elise: 100%|██████████| 950/950 [00:00<00:00, 232323.99it/s]
# Creating Piano roll: Bagatella op33 n1: 100%|██████████| 1636/1636 [00:00<00:00, 177750.53it/s]
# Creating Piano roll: Bagatella op33 n2: 100%|██████████| 1865/1865 [00:00<00:00, 232663.42it/s]
# Creating Piano roll: Bagatella op33 n3: 100%|██████████| 1019/1019 [00:00<00:00, 203970.40it/s]
# Creating Piano roll: Bagatella op33 n4: 100%|██████████| 1063/1063 [00:00<00:00, 115127.56it/s]
# Creating Piano roll: Bagatella op33 n5: 100%|██████████| 2393/2393 [00:00<00:00, 192378.61it/s]
# Creating Piano roll: Bagatella op33 n6: 100%|██████████| 1017/1017 [00:00<00:00, 162977.39it/s]
# Creating Piano roll: Fur Elise: 100%|██████████| 2102/2102 [00:00<00:00, 182871.69it/s]
# Creating Piano roll: Hess057 Bagatella: 100%|██████████| 408/408 [00:00<00:00, 136085.57it/s]
# Creating Piano roll: Hess059 Exercizio Per Pianoforte: 100%|██████████| 461/461 [00:00<00:00, 153824.51it/s]
# Creating Piano roll: Hess061 Anglaise: 100%|██████████| 357/357 [00:00<00:00, 178427.85it/s]
# Creating Piano roll: Hess063 keyb Kaplied: 100%|██████████| 139/139 [00:00<00:00, 139010.08it/s]
# Creating Piano roll: Hess073 Bagatella: 100%|██████████| 158/158 [00:00<00:00, 71450.14it/s]
# Creating Piano roll: Hess074 Bagatella: 100%|██████████| 534/534 [00:00<00:00, 177913.92it/s]
# Creating Piano roll: HessA21 Bagatella: 100%|██████████| 393/393 [00:00<00:00, 196443.98it/s]
# Creating Piano roll: Lieder op46 ''Adelaide'': 100%|██████████| 3703/3703 [00:00<00:00, 74790.45it/s]
# Creating Piano roll: Lieder op48 n1 ''Bitten'': 100%|██████████| 487/487 [00:00<00:00, 151406.57it/s]
# Creating Piano roll: Lieder op48 n2 ''Die Liebe Des Nachsten'': 100%|██████████| 308/308 [00:00<00:00, 102535.57it/s]
# Creating Piano roll: Lieder op48 n3 ''Vom Tode'': 100%|██████████| 409/409 [00:00<00:00, 102251.32it/s]
# Creating Piano roll: Lieder op48 n4 ''Die Ehre Gottes Aus Der Natur'': 100%|██████████| 708/708 [00:00<00:00, 177202.96it/s]
# Creating Piano roll: Lieder op48 n5 ''Gottes Macht Und Vorsehung'': 100%|██████████| 196/196 [00:00<00:00, 98288.33it/s]
# Creating Piano roll: Lieder op48 n6 ''Busslied'': 100%|██████████| 1974/1974 [00:00<00:00, 219250.49it/s]
# Creating Piano roll: Lieder op82 n1 ''Dimmi Den Mio Che Mi Ami'': 100%|██████████| 1202/1202 [00:00<00:00, 200363.78it/s]
# Creating Piano roll: Lieder op99 ''Der Mann Von Wort'': 100%|██████████| 817/817 [00:00<00:00, 203561.03it/s]
# Creating Piano roll: March No.3: 100%|██████████| 10415/10415 [00:00<00:00, 218438.04it/s]
# Creating Piano roll: Minuetto: 100%|██████████| 352/352 [00:00<00:00, 117472.55it/s]
# Creating Piano roll: Op.51: 100%|██████████| 2697/2697 [00:00<00:00, 207499.41it/s]
# Creating Piano roll: op051 3 Rondos: 100%|██████████| 6664/6664 [00:00<00:00, 203051.43it/s]
# Creating Piano roll: op077 Fantaisie: 100%|██████████| 4879/4879 [00:00<00:00, 217436.21it/s]
# Creating Piano roll: op089 Polonaise: 100%|██████████| 4457/4457 [00:00<00:00, 219914.04it/s]
# Creating Piano roll: op119 Douze Bagatellas: 100%|██████████| 5757/5757 [00:00<00:00, 212700.47it/s]
# Creating Piano roll: op126 Six Bagatellas: 100%|██████████| 6010/6010 [00:00<00:00, 223601.96it/s]
# Creating Piano roll: Op33 No.4: 100%|██████████| 1060/1060 [00:00<00:00, 169009.44it/s]
# Creating Piano roll: Opus045 Three Grandes Marches: 100%|██████████| 10495/10495 [00:00<00:00, 213161.94it/s]
# Creating Piano roll: Overture ''Corolian'' op62: 100%|██████████| 10828/10828 [00:00<00:00, 161411.69it/s]
# Creating Piano roll: Overture ''Creatures Of Prometeus'' op43: 100%|██████████| 9586/9586 [00:00<00:00, 233298.12it/s]
# Creating Piano roll: Overture ''Egmont'': 100%|██████████| 12748/12748 [00:00<00:00, 224616.20it/s]
# Creating Piano roll: Overture ''Fidelio'' op72b: 100%|██████████| 13251/13251 [00:00<00:00, 223732.46it/s]
# Creating Piano roll: Overture ''Inauguration of the House'' op214: 100%|██████████| 25300/25300 [00:00<00:00, 230175.33it/s]
# Creating Piano roll: Overture ''King Stephen'': 100%|██████████| 17577/17577 [00:00<00:00, 212257.17it/s]
# Creating Piano roll: Overture ''Leonore'' n2 op72: 100%|██████████| 20293/20293 [00:00<00:00, 214663.69it/s]
# Creating Piano roll: Overture ''Leonore'' n3 op72: 100%|██████████| 21845/21845 [00:00<00:00, 220267.26it/s]
# Creating Piano roll: Overture ''Leonore'' op138 n1: 100%|██████████| 12964/12964 [00:00<00:00, 203647.71it/s]
# Creating Piano roll: Piano Concerto n1 op15 1mov: 100%|██████████| 16828/16828 [00:00<00:00, 211115.91it/s]
# Creating Piano roll: Piano Concerto n1 op15 2mov: 100%|██████████| 5683/5683 [00:00<00:00, 208533.64it/s]
# Creating Piano roll: Piano Concerto n1 op15 3mov: 100%|██████████| 15095/15095 [00:00<00:00, 221125.23it/s]
# Creating Piano roll: Piano Concerto n2 op19 1mov: 100%|██████████| 14128/14128 [00:00<00:00, 186966.98it/s]
# Creating Piano roll: Piano Concerto n2 op19 2mov: 100%|██████████| 3982/3982 [00:00<00:00, 222808.41it/s]
# Creating Piano roll: Piano Concerto n2 op19 3mov: 100%|██████████| 8232/8232 [00:00<00:00, 227545.39it/s]
# Creating Piano roll: Piano Concerto n3 op37 1mov: 100%|██████████| 18909/18909 [00:00<00:00, 182804.49it/s]
# Creating Piano roll: Piano Concerto n3 op37 2mov: 100%|██████████| 3807/3807 [00:00<00:00, 217309.92it/s]
# Creating Piano roll: Piano Concerto n3 op37 3mov: 100%|██████████| 14511/14511 [00:00<00:00, 231765.77it/s]
# Creating Piano roll: Piano Concerto n4 op58 1mov: 100%|██████████| 19092/19092 [00:00<00:00, 231686.73it/s]
# Creating Piano roll: Piano Concerto n4 op58 2mov: 100%|██████████| 1664/1664 [00:00<00:00, 221974.49it/s]
# Creating Piano roll: Piano Concerto n4 op58 3mov: 100%|██████████| 13044/13044 [00:00<00:00, 228506.93it/s]
# Creating Piano roll: Piano Concerto n5 op73 1mov ''Emperor'': 100%|██████████| 29515/29515 [00:00<00:00, 228512.20it/s]
# Creating Piano roll: Piano Concerto n5 op73 2-3mov ''Emperor'': 100%|██████████| 20464/20464 [00:00<00:00, 202747.73it/s]
# Creating Piano roll: Piano Concerto No5,Mov.1: 100%|██████████| 25951/25951 [00:00<00:00, 201793.83it/s]
# Creating Piano roll: Piano Concerto No5,Mov.3: 100%|██████████| 16488/16488 [00:00<00:00, 201442.71it/s]
# Creating Piano roll: Piano Romance  No.50: 100%|██████████| 3525/3525 [00:00<00:00, 219325.06it/s]
# Creating Piano roll: Piano Sonata n01: 100%|██████████| 7332/7332 [00:00<00:00, 183505.81it/s]
# Creating Piano roll: Piano Sonata n02: 100%|██████████| 9340/9340 [00:00<00:00, 205031.74it/s]
# Creating Piano roll: Piano Sonata n03: 100%|██████████| 11915/11915 [00:00<00:00, 211997.08it/s]
# Creating Piano roll: Piano Sonata n04: 100%|██████████| 12248/12248 [00:00<00:00, 220747.15it/s]
# Creating Piano roll: Piano Sonata n05: 100%|██████████| 7229/7229 [00:00<00:00, 220146.98it/s]
# Creating Piano roll: Piano Sonata n06: 100%|██████████| 7171/7171 [00:00<00:00, 226019.76it/s]
# Creating Piano roll: Piano Sonata n07: 100%|██████████| 9201/9201 [00:00<00:00, 230239.30it/s]
# Creating Piano roll: Piano Sonata n08 op13 1mov ''Pathetique'': 100%|██████████| 5890/5890 [00:00<00:00, 123312.62it/s]
# Creating Piano roll: Piano Sonata n08 op13 2mov ''Pathetique'': 100%|██████████| 1636/1636 [00:00<00:00, 145037.76it/s]
# Creating Piano roll: Piano Sonata n08 op13 3mov ''Pathetique'': 100%|██████████| 2391/2391 [00:00<00:00, 207755.81it/s]
# Creating Piano roll: Piano Sonata n09: 100%|██████████| 5706/5706 [00:00<00:00, 229317.29it/s]
# Creating Piano roll: Piano Sonata n10 1mov: 100%|██████████| 3390/3390 [00:00<00:00, 165199.15it/s]
# Creating Piano roll: Piano Sonata n10 2mov: 100%|██████████| 2048/2048 [00:00<00:00, 221452.85it/s]
# Creating Piano roll: Piano Sonata n10: 100%|██████████| 7428/7428 [00:00<00:00, 214532.65it/s]
# Creating Piano roll: Piano Sonata n11: 100%|██████████| 12752/12752 [00:00<00:00, 224329.51it/s]
# Creating Piano roll: Piano Sonata n12 op26: 100%|██████████| 9053/9053 [00:00<00:00, 216818.75it/s]
# Creating Piano roll: Piano Sonata n13: 100%|██████████| 8347/8347 [00:00<00:00, 227658.99it/s]
# Creating Piano roll: Piano Sonata n14 op27  ''Moonlight'': 100%|██████████| 8584/8584 [00:00<00:00, 229886.51it/s]
# Creating Piano roll: Piano Sonata n14 op27 1mov ''Moonlight'': 100%|██████████| 1144/1144 [00:00<00:00, 122361.50it/s]
# Creating Piano roll: Piano Sonata n14 op27 2mov ''Moonlight'': 100%|██████████| 895/895 [00:00<00:00, 219154.77it/s]
# Creating Piano roll: Piano Sonata n14 op27 3mov ''Moonlight'': 100%|██████████| 6527/6527 [00:00<00:00, 221193.40it/s]
# Creating Piano roll: Piano Sonata n15 ''Pastoral'': 100%|██████████| 11576/11576 [00:00<00:00, 229210.79it/s]
# Creating Piano roll: Piano Sonata n15 2mov ''Pastoral'': 100%|██████████| 2388/2388 [00:00<00:00, 200938.85it/s]
# Creating Piano roll: Piano Sonata n15 3mov ''Pastoral'': 100%|██████████| 1212/1212 [00:00<00:00, 202078.89it/s]
# Creating Piano roll: Piano Sonata n16: 100%|██████████| 12239/12239 [00:00<00:00, 225329.37it/s]
# Creating Piano roll: Piano Sonata n17 ''Tempestat'': 100%|██████████| 7905/7905 [00:00<00:00, 224525.96it/s]
# Creating Piano roll: Piano Sonata n18 ''The Hunt'': 100%|██████████| 8972/8972 [00:00<00:00, 234794.98it/s]
# Creating Piano roll: Piano Sonata n19: 100%|██████████| 3362/3362 [00:00<00:00, 227980.05it/s]
# Creating Piano roll: Piano Sonata n20: 100%|██████████| 2937/2937 [00:00<00:00, 83112.96it/s]
# Creating Piano roll: Piano Sonata n21 1mov ''Waldstein'': 100%|██████████| 8573/8573 [00:00<00:00, 202459.21it/s]
# Creating Piano roll: Piano Sonata n21 2mov ''Waldstein'': 100%|██████████| 493/493 [00:00<00:00, 123303.03it/s]
# Creating Piano roll: Piano Sonata n21 3mov ''Waldstein'': 100%|██████████| 7359/7359 [00:00<00:00, 215477.67it/s]
# Creating Piano roll: Piano Sonata n22: 100%|██████████| 5802/5802 [00:00<00:00, 190852.03it/s]
# Creating Piano roll: Piano Sonata n23 op57 1mov ''Apassionata'': 100%|██████████| 6376/6376 [00:00<00:00, 211369.42it/s]
# Creating Piano roll: Piano Sonata n23 op57 2mov ''Apassionata'': 100%|██████████| 1981/1981 [00:00<00:00, 239961.77it/s]
# Creating Piano roll: Piano Sonata n23 op57 3mov ''Apassionata'': 100%|██████████| 7223/7223 [00:00<00:00, 227828.22it/s]
# Creating Piano roll: Piano Sonata n24: 100%|██████████| 4619/4619 [00:00<00:00, 212021.78it/s]
# Creating Piano roll: Piano Sonata n25: 100%|██████████| 4260/4260 [00:00<00:00, 222011.84it/s]
# Creating Piano roll: Piano sonata n26 ''Les Adieux'': 100%|██████████| 7416/7416 [00:00<00:00, 181872.69it/s]
# Creating Piano roll: Piano Sonata n27: 100%|██████████| 6643/6643 [00:00<00:00, 188918.01it/s]
# Creating Piano roll: Piano Sonata n28: 100%|██████████| 8467/8467 [00:00<00:00, 228611.34it/s]
# Creating Piano roll: Piano Sonata n29 Op106 ''Hammerklavier'': 100%|██████████| 24185/24185 [00:00<00:00, 210516.88it/s]
# Creating Piano roll: Piano Sonata n30: 100%|██████████| 8713/8713 [00:00<00:00, 133020.44it/s]
# Creating Piano roll: Piano Sonata n31 op110: 100%|██████████| 8075/8075 [00:00<00:00, 181334.89it/s]
# Creating Piano roll: Piano sonata n32 op111: 100%|██████████| 13470/13470 [00:00<00:00, 177211.33it/s]
# Creating Piano roll: Piano Sonata No 28 in B flat -Hammerklavier- Op.106, 2nd Mov Scherzo: 100%|██████████| 1888/1888 [00:00<00:00, 205178.03it/s]
# Creating Piano roll: Piano Sonata No.27,  3rd mov: 100%|██████████| 6491/6491 [00:00<00:00, 223832.77it/s]
# Creating Piano roll: Piano Sonata No.27: 100%|██████████| 1442/1442 [00:00<00:00, 205937.77it/s]
# Creating Piano roll: Piano Sonata No2 Assai vivace: 100%|██████████| 1888/1888 [00:00<00:00, 230560.94it/s]
# Creating Piano roll: Piano Sonatina in G Op79: 100%|██████████| 5925/5925 [00:00<00:00, 231266.94it/s]
# Creating Piano roll: Piano Sonatina No.2 Op 49: 100%|██████████| 3389/3389 [00:00<00:00, 256755.47it/s]
# Creating Piano roll: Preludes 2 Through Major keys 39: 100%|██████████| 2546/2546 [00:00<00:00, 212194.69it/s]
# Creating Piano roll: Rage over a lost pennny: 100%|██████████| 5591/5591 [00:00<00:00, 243056.70it/s]
# Creating Piano roll: Romance piano: 100%|██████████| 3525/3525 [00:00<00:00, 223671.68it/s]
# Creating Piano roll: Rondo in B flat: 100%|██████████| 4386/4386 [00:00<00:00, 230688.03it/s]
# Creating Piano roll: Rondo Opus.51, No.1: 100%|██████████| 2674/2674 [00:00<00:00, 235888.80it/s]
# Creating Piano roll: Rondo Opus.51, No.2: 100%|██████████| 3971/3971 [00:00<00:00, 188768.16it/s]
# Creating Piano roll: Sechs Variationen: 100%|██████████| 2477/2477 [00:00<00:00, 80878.84it/s]
# Creating Piano roll: Seven Inversions of God Save the King: 100%|██████████| 3774/3774 [00:00<00:00, 78350.48it/s]
# Creating Piano roll: Sieben Bagatellen, C Major, Opus.33, No.2: 100%|██████████| 1865/1865 [00:00<00:00, 105358.97it/s]
# Creating Piano roll: Sieben Bagatellen, in A Major, Opus.33, No.4: 100%|██████████| 1063/1063 [00:00<00:00, 132872.75it/s]
# Creating Piano roll: Sieben Bagatellen, in C Major, Opus.33, No.5: 100%|██████████| 2393/2393 [00:00<00:00, 130238.62it/s]
# Creating Piano roll: Sieben Bagatellen, in D Major, Opus.33, No.6: 100%|██████████| 1017/1017 [00:00<00:00, 58086.84it/s]
# Creating Piano roll: Sieben Bagatellen, in E flat Major, Opus.33, No.1: 100%|██████████| 1636/1636 [00:00<00:00, 164372.19it/s]
# Creating Piano roll: Sieben Bagatellen, in F Major, Opus.33, No.3: 100%|██████████| 1019/1019 [00:00<00:00, 169569.36it/s]
# Creating Piano roll: Sketch for Piano Alla Marcia: 100%|██████████| 252/252 [00:00<00:00, 83966.05it/s]
# Creating Piano roll: Sketch for Piano Allegretto: 100%|██████████| 350/350 [00:00<00:00, 156437.17it/s]
# Creating Piano roll: Sketch for Piano Allegro Giocoso: 100%|██████████| 131/131 [00:00<00:00, 43673.30it/s]
# Creating Piano roll: Sketch for Piano Allegro: 100%|██████████| 213/213 [00:00<00:00, 212609.89it/s]
# Creating Piano roll: Sketch for Piano Presto: 100%|██████████| 690/690 [00:00<00:00, 152576.43it/s]
# Creating Piano roll: Sonata in Bflat Major Op.106: 100%|██████████| 1888/1888 [00:00<00:00, 104907.61it/s]
# Creating Piano roll: Sonata No.14 Op 27 Moonlight Sonata: 100%|██████████| 1141/1141 [00:00<00:00, 103725.80it/s]
# Creating Piano roll: Sonata No.14 Op 27 Sonata Quasi Una Fantasia: 100%|██████████| 894/894 [00:00<00:00, 223676.20it/s]
# Creating Piano roll: Sonata op78 1st mov: 100%|██████████| 3360/3360 [00:00<00:00, 197661.39it/s]
# Creating Piano roll: Sonata Opus.81a -Les Adieux- E flat No.1: 100%|██████████| 3282/3282 [00:00<00:00, 229600.63it/s]
# Creating Piano roll: Sonata Opus.81a -Les Adieux- E flat No.2 & 3: 100%|██████████| 6222/6222 [00:00<00:00, 214389.24it/s]
# Creating Piano roll: Sonata Presto: 100%|██████████| 3389/3389 [00:00<00:00, 225956.89it/s]
# Creating Piano roll: Sonata, Opus.111 C minor No.1: 100%|██████████| 5450/5450 [00:00<00:00, 200873.10it/s]
# Creating Piano roll: Sonata, Opus.111 C minor No.2: 100%|██████████| 7978/7978 [00:00<00:00, 218142.31it/s]
# Creating Piano roll: Sonatina Fa maj woo: 100%|██████████| 2373/2373 [00:00<00:00, 215883.29it/s]
# Creating Piano roll: Sonatina In C: 100%|██████████| 2814/2814 [00:00<00:00, 196352.88it/s]
# Creating Piano roll: Sonatina n1 op05: 100%|██████████| 1159/1159 [00:00<00:00, 165527.05it/s]
# Creating Piano roll: Sonatina op33 4mov: 100%|██████████| 1060/1060 [00:00<00:00, 176287.16it/s]
# Creating Piano roll: Sonatina WoO050: 100%|██████████| 1845/1845 [00:00<00:00, 147627.59it/s]
# Creating Piano roll: String Quartet n1 op18 1mov: 100%|██████████| 6101/6101 [00:00<00:00, 225963.38it/s]
# Creating Piano roll: String Quartet n1 op18 2mov: 100%|██████████| 3220/3220 [00:00<00:00, 144525.93it/s]
# Creating Piano roll: String Quartet n1 op18 3mov: 100%|██████████| 3190/3190 [00:00<00:00, 135306.97it/s]
# Creating Piano roll: String Quartet n1 op18 4mov: 100%|██████████| 5386/5386 [00:00<00:00, 148779.44it/s]
# Creating Piano roll: String Quartet n16 op135 1mov: 100%|██████████| 3369/3369 [00:00<00:00, 207613.80it/s]
# Creating Piano roll: String Quartet n16 op135 2mov: 100%|██████████| 3927/3927 [00:00<00:00, 214718.18it/s]
# Creating Piano roll: String Quartet n16 op135 3mov: 100%|██████████| 1063/1063 [00:00<00:00, 212554.59it/s]
# Creating Piano roll: String Quartet n16 op135 4mov: 100%|██████████| 6258/6258 [00:00<00:00, 207295.43it/s]
# Creating Piano roll: String Quartet n2 op18 n2 1mov: 100%|██████████| 4204/4204 [00:00<00:00, 197688.82it/s]
# Creating Piano roll: String Quartet n2 op18 n2 2mov: 100%|██████████| 2243/2243 [00:00<00:00, 184308.12it/s]
# Creating Piano roll: String Quartet n2 op18 n2 3mov: 100%|██████████| 3012/3012 [00:00<00:00, 182313.67it/s]
# Creating Piano roll: String Quartet n2 op18 n2 4mov: 100%|██████████| 4143/4143 [00:00<00:00, 197277.62it/s]
# Creating Piano roll: Symphony n1 1mov: 100%|██████████| 16259/16259 [00:00<00:00, 220030.62it/s]
# Creating Piano roll: Symphony n1 2mov: 100%|██████████| 7460/7460 [00:00<00:00, 207208.42it/s]
# Creating Piano roll: Symphony n1 3mov: 100%|██████████| 6906/6906 [00:00<00:00, 226022.11it/s]
# Creating Piano roll: Symphony n1 4mov: 100%|██████████| 11001/11001 [00:00<00:00, 142852.18it/s]
# Creating Piano roll: Symphony n2 op36 1mov: 100%|██████████| 24328/24328 [00:00<00:00, 218636.63it/s]
# Creating Piano roll: Symphony n2 op36 2mov: 100%|██████████| 8754/8754 [00:00<00:00, 216209.64it/s]
# Creating Piano roll: Symphony n2 op36 3mov: 100%|██████████| 5610/5610 [00:00<00:00, 216445.86it/s]
# Creating Piano roll: Symphony n2 op36 4mov: 100%|██████████| 14119/14119 [00:00<00:00, 231796.53it/s]
# Creating Piano roll: Symphony n3 1mov ''Eroica'': 100%|██████████| 30718/30718 [00:00<00:00, 228848.62it/s]
# Creating Piano roll: Symphony n3 2mov ''Eroica'': 100%|██████████| 9755/9755 [00:00<00:00, 218280.85it/s]
# Creating Piano roll: Symphony n3 3mov ''Eroica'': 100%|██████████| 11870/11870 [00:00<00:00, 183217.37it/s]
# Creating Piano roll: Symphony n3 4mov ''Eroica'': 100%|██████████| 17324/17324 [00:00<00:00, 230729.07it/s]
# Creating Piano roll: Symphony n4 1mov: 100%|██████████| 17215/17215 [00:00<00:00, 220590.98it/s]
# Creating Piano roll: Symphony n4 2mov: 100%|██████████| 6610/6610 [00:00<00:00, 206451.33it/s]
# Creating Piano roll: Symphony n4 3mov: 100%|██████████| 8721/8721 [00:00<00:00, 196498.16it/s]
# Creating Piano roll: Symphony n4 4mov: 100%|██████████| 14626/14626 [00:00<00:00, 236149.18it/s]
# Creating Piano roll: Symphony n5 op67 1mov: 100%|██████████| 9305/9305 [00:00<00:00, 227695.96it/s]
# Creating Piano roll: Symphony n5 op67 3-4mov: 100%|██████████| 33835/33835 [00:00<00:00, 134903.35it/s]
# Creating Piano roll: Symphony n7 1mov: 100%|██████████| 25180/25180 [00:00<00:00, 164240.28it/s]
# Creating Piano roll: Symphony n7 2mov: 100%|██████████| 6059/6059 [00:00<00:00, 214085.96it/s]
# Creating Piano roll: Symphony n7 3mov: 100%|██████████| 16476/16476 [00:00<00:00, 236093.76it/s]
# Creating Piano roll: Symphony n7 4mov: 100%|██████████| 25934/25934 [00:00<00:00, 222855.46it/s]
# Creating Piano roll: Symphony op125 n9 1mov ''Choral'': 100%|██████████| 29427/29427 [00:00<00:00, 231748.95it/s]
# Creating Piano roll: Symphony op125 n9 2mov ''Choral'': 100%|██████████| 34834/34834 [00:00<00:00, 203428.22it/s]
# Creating Piano roll: Symphony op125 n9 3mov ''Choral'': 100%|██████████| 8495/8495 [00:00<00:00, 215761.34it/s]
# Creating Piano roll: Symphony op125 n9 4mov ''Choral'': 100%|██████████| 47701/47701 [00:00<00:00, 165630.88it/s]
# Creating Piano roll: Symphony op68 n6 ''Pastorale'': 100%|██████████| 44836/44836 [00:00<00:00, 216721.83it/s]
# Creating Piano roll: Symphony op68 n6 1mov ''Pastorale'': 100%|██████████| 16006/16006 [00:00<00:00, 221079.98it/s]
# Creating Piano roll: Symphony op68 n6 2mov ''Pastorale'': 100%|██████████| 13609/13609 [00:00<00:00, 218091.76it/s]
# Creating Piano roll: Symphony op68 n6 3mov ''Pastorale'': 100%|██████████| 32907/32907 [00:00<00:00, 234470.84it/s]
# Creating Piano roll: Symphony op93 n8 1mov: 100%|██████████| 19576/19576 [00:00<00:00, 206524.91it/s]
# Creating Piano roll: Symphony op93 n8 2mov : 100%|██████████| 5730/5730 [00:00<00:00, 197490.11it/s]
# Creating Piano roll: Symphony op93 n8 3mov : 100%|██████████| 5924/5924 [00:00<00:00, 192259.62it/s]
# Creating Piano roll: Symphony op93 n8 4mov: 100%|██████████| 20768/20768 [00:00<00:00, 226213.96it/s]
# Creating Piano roll: Violin Concerto op61 1mov: 100%|██████████| 19867/19867 [00:00<00:00, 165042.36it/s]
# Creating Piano roll: Violin Concerto op61 2-3movs: 100%|██████████| 13628/13628 [00:00<00:00, 222830.27it/s]
# Creating Piano roll: WoO010 Six Menuets for Orchestra: 100%|██████████| 4480/4480 [00:00<00:00, 143251.80it/s]
# Creating Piano roll: WoO048 Rondo: 100%|██████████| 1196/1196 [00:00<00:00, 72385.50it/s]
# Creating Piano roll: WoO049 Rondo: 100%|██████████| 1179/1179 [00:00<00:00, 75109.88it/s]
# Creating Piano roll: WoO051 Sonatina 1-2 movs: 100%|██████████| 2970/2970 [00:00<00:00, 191403.02it/s]
# Creating Piano roll: WoO052 Bagatella: 100%|██████████| 4060/4060 [00:00<00:00, 189510.83it/s]
# Creating Piano roll: WoO054 Lustig Traurig: 100%|██████████| 636/636 [00:00<00:00, 127033.54it/s]
# Creating Piano roll: WoO055 Prelude: 100%|██████████| 883/883 [00:00<00:00, 76608.69it/s]
# Creating Piano roll: WoO056 Bagatella: 100%|██████████| 682/682 [00:00<00:00, 136416.39it/s]
# Creating Piano roll: WoO060 Mouvement Pour Piano: 100%|██████████| 299/299 [00:00<00:00, 74813.39it/s]
# Creating Piano roll: WoO061 Mouvement Pour Piano: 100%|██████████| 462/462 [00:00<00:00, 115501.49it/s]
# Creating Piano roll: WoO061a Mouvement Pour Piano: 100%|██████████| 90/90 [00:00<00:00, 45024.73it/s]
# Creating Piano roll: WoO081 Allemande: 100%|██████████| 604/604 [00:00<00:00, 302346.30it/s]
# Creating Piano roll: WoO082 Menuet: 100%|██████████| 1772/1772 [00:00<00:00, 177157.93it/s]
# Creating Piano roll: WoO083 Six Escotish Dances for Piano: 100%|██████████| 1238/1238 [00:00<00:00, 207760.11it/s]
# Creating Piano roll: WoO086 Scotish: 100%|██████████| 211/211 [00:00<00:00, 105570.58it/s]
# Creating Piano roll: 003706b_: 100%|██████████| 304/304 [00:00<00:00, 152011.02it/s]
# Creating Piano roll: 003806b_: 100%|██████████| 253/253 [00:00<00:00, 84025.57it/s]
# Creating Piano roll: 003907bv: 100%|██████████| 285/285 [00:00<00:00, 51709.85it/s]
# Creating Piano roll: 003907b_: 100%|██████████| 285/285 [00:00<00:00, 71242.42it/s]
# Creating Piano roll: 004003b_: 100%|██████████| 204/204 [00:00<00:00, 102116.96it/s]
# Creating Piano roll: 004006b_: 100%|██████████| 250/250 [00:00<00:00, 124934.59it/s]
# Creating Piano roll: 004008b_: 100%|██████████| 358/358 [00:00<00:00, 59663.88it/s]
# Creating Piano roll: 004106bs: 100%|██████████| 541/541 [00:00<00:00, 49174.72it/s]
# Creating Piano roll: 004106b_: 100%|██████████| 927/927 [00:00<00:00, 186937.82it/s]
# Creating Piano roll: 004207b_: 100%|██████████| 599/599 [00:00<00:00, 149841.24it/s]
# Creating Piano roll: 004311b_: 100%|██████████| 261/261 [00:00<00:00, 65258.62it/s]
# Creating Piano roll: 004407b_: 100%|██████████| 208/208 [00:00<00:00, 103945.58it/s]
# Creating Piano roll: 004507b_: 100%|██████████| 297/297 [00:00<00:00, 98944.26it/s]
# Creating Piano roll: 004606bs: 100%|██████████| 239/239 [00:00<00:00, 119622.75it/s]
# Creating Piano roll: 004606b_: 100%|██████████| 841/841 [00:00<00:00, 210190.06it/s]
# Creating Piano roll: 004705b_: 100%|██████████| 186/186 [00:00<00:00, 185969.14it/s]
# Creating Piano roll: 004803b_: 100%|██████████| 157/157 [00:00<00:00, 39299.70it/s]
# Creating Piano roll: 004807b_: 100%|██████████| 280/280 [00:00<00:00, 92045.23it/s]
# Creating Piano roll: 005206b_: 100%|██████████| 323/323 [00:00<00:00, 107665.91it/s]
# Creating Piano roll: 005505b_: 100%|██████████| 278/278 [00:00<00:00, 277887.63it/s]
# Creating Piano roll: 005605b_: 100%|██████████| 353/353 [00:00<00:00, 175946.44it/s]
# Creating Piano roll: 005708b_: 100%|██████████| 213/213 [00:00<00:00, 70864.34it/s]
# Creating Piano roll: 005903b_: 100%|██████████| 745/745 [00:00<00:00, 248371.07it/s]
# Creating Piano roll: 006005b_: 100%|██████████| 282/282 [00:00<00:00, 283168.24it/s]
# Creating Piano roll: 006106b_: 100%|██████████| 551/551 [00:00<00:00, 137743.56it/s]
# Creating Piano roll: 006206bv: 100%|██████████| 188/188 [00:00<00:00, 93538.45it/s]
# Creating Piano roll: 006206b_: 100%|██████████| 188/188 [00:00<00:00, 181688.74it/s]
# Creating Piano roll: 006402b_: 100%|██████████| 173/173 [00:00<00:00, 144602.35it/s]
# Creating Piano roll: 006404b_: 100%|██████████| 368/368 [00:00<00:00, 182922.95it/s]
# Creating Piano roll: 006408b_: 100%|██████████| 272/272 [00:00<00:00, 136058.52it/s]
# Creating Piano roll: 006502b_: 100%|██████████| 147/147 [00:00<00:00, 146765.70it/s]
# Creating Piano roll: 006507b_: 100%|██████████| 332/332 [00:00<00:00, 98724.49it/s]
# Creating Piano roll: 006606b_: 100%|██████████| 163/163 [00:00<00:00, 163089.59it/s]
# Creating Piano roll: 006704b_: 100%|██████████| 173/173 [00:00<00:00, 173426.05it/s]
# Creating Piano roll: 006707b_: 100%|██████████| 190/190 [00:00<00:00, 31660.15it/s]
# Creating Piano roll: 006906ba: 100%|██████████| 305/305 [00:00<00:00, 50802.70it/s]
# Creating Piano roll: 006906bav: 100%|██████████| 245/245 [00:00<00:00, 81627.17it/s]
# Creating Piano roll: 006906b_: 100%|██████████| 619/619 [00:00<00:00, 88456.07it/s]
# Creating Piano roll: 007007b_: 100%|██████████| 276/276 [00:00<00:00, 138026.46it/s]
# Creating Piano roll: 007011b_: 100%|██████████| 388/388 [00:00<00:00, 97047.53it/s]
# Creating Piano roll: 007011ch: 100%|██████████| 221/221 [00:00<00:00, 110560.73it/s]
# Creating Piano roll: 007206b_: 100%|██████████| 409/409 [00:00<00:00, 45381.61it/s]
# Creating Piano roll: 007305bv: 100%|██████████| 233/233 [00:00<00:00, 58292.44it/s]
# Creating Piano roll: 007305b_: 100%|██████████| 233/233 [00:00<00:00, 73684.15it/s]
# Creating Piano roll: 007408b_: 100%|██████████| 257/257 [00:00<00:00, 128448.06it/s]
# Creating Piano roll: 007507b_: 100%|██████████| 1256/1256 [00:00<00:00, 178517.31it/s]
# Creating Piano roll: 007514b_: 100%|██████████| 1256/1256 [00:00<00:00, 209207.17it/s]
# Creating Piano roll: 007607b_: 100%|██████████| 1393/1393 [00:00<00:00, 199048.32it/s]
# Creating Piano roll: 007614b_: 100%|██████████| 1393/1393 [00:00<00:00, 154797.20it/s]
# Creating Piano roll: 007706b_: 100%|██████████| 255/255 [00:00<00:00, 127554.86it/s]
# Creating Piano roll: 007807b_: 100%|██████████| 283/283 [00:00<00:00, 70658.26it/s]
# Creating Piano roll: 007903bs: 100%|██████████| 215/215 [00:00<00:00, 215529.48it/s]
# Creating Piano roll: 007903b_: 100%|██████████| 1230/1230 [00:00<00:00, 233248.66it/s]
# Creating Piano roll: 007906b_: 100%|██████████| 231/231 [00:00<00:00, 115028.40it/s]
# Creating Piano roll: 008008b_: 100%|██████████| 338/338 [00:00<00:00, 338427.97it/s]
# Creating Piano roll: 008107b_: 100%|██████████| 283/283 [00:00<00:00, 278570.30it/s]
# Creating Piano roll: 008305b_: 100%|██████████| 202/202 [00:00<00:00, 132610.64it/s]
# Creating Piano roll: 008405b_: 100%|██████████| 218/218 [00:00<00:00, 72666.16it/s]
# Creating Piano roll: 008506b_: 100%|██████████| 292/292 [00:00<00:00, 146184.86it/s]
# Creating Piano roll: 008606b_: 100%|██████████| 270/270 [00:00<00:00, 133136.85it/s]
# Creating Piano roll: 008707b_: 100%|██████████| 314/314 [00:00<00:00, 104690.89it/s]
# Creating Piano roll: 008807b_: 100%|██████████| 245/245 [00:00<00:00, 240600.44it/s]
# Creating Piano roll: 008906b_: 100%|██████████| 193/193 [00:00<00:00, 192921.99it/s]
# Creating Piano roll: 009005b_: 100%|██████████| 234/234 [00:00<00:00, 78036.67it/s]
# Creating Piano roll: 009106b_: 100%|██████████| 336/336 [00:00<00:00, 112159.66it/s]
# Creating Piano roll: 009106ch: 100%|██████████| 197/197 [00:00<00:00, 65562.00it/s]
# Creating Piano roll: 009207b_: 100%|██████████| 693/693 [00:00<00:00, 173262.56it/s]
# Creating Piano roll: 009209b_: 100%|██████████| 320/320 [00:00<00:00, 145131.63it/s]
# Creating Piano roll: 009307b_: 100%|██████████| 220/220 [00:00<00:00, 108405.41it/s]
# Creating Piano roll: 009408b_: 100%|██████████| 239/239 [00:00<00:00, 119394.79it/s]
# Creating Piano roll: 009507b_: 100%|██████████| 347/347 [00:00<00:00, 115656.67it/s]
# Creating Piano roll: 009606b_: 100%|██████████| 219/219 [00:00<00:00, 73933.72it/s]
# Creating Piano roll: 009709b_: 100%|██████████| 388/388 [00:00<00:00, 129373.56it/s]
# Creating Piano roll: 009709ch: 100%|██████████| 221/221 [00:00<00:00, 55171.79it/s]
# Creating Piano roll: 009801b_: 100%|██████████| 2562/2562 [00:00<00:00, 206527.01it/s]
# Creating Piano roll: 009906b_: 100%|██████████| 273/273 [00:00<00:00, 272435.16it/s]
# Creating Piano roll: 01 Menuet: 100%|██████████| 524/524 [00:00<00:00, 174707.10it/s]
# Creating Piano roll: 01. Kyrie Eleison : 100%|██████████| 8934/8934 [00:00<00:00, 127995.76it/s]
# Creating Piano roll: 010006b_: 100%|██████████| 2389/2389 [00:00<00:00, 58270.48it/s]
# Creating Piano roll: 010107bv: 100%|██████████| 326/326 [00:00<00:00, 54205.87it/s]
# Creating Piano roll: 010107b_: 100%|██████████| 314/314 [00:00<00:00, 44881.80it/s]
# Creating Piano roll: 010207b_: 100%|██████████| 228/228 [00:00<00:00, 76096.23it/s]
# Creating Piano roll: 010306b_: 100%|██████████| 325/325 [00:00<00:00, 49901.12it/s]
# Creating Piano roll: 010406bv: 100%|██████████| 280/280 [00:00<00:00, 70017.59it/s]
# Creating Piano roll: 010406b_: 100%|██████████| 280/280 [00:00<00:00, 140076.95it/s]
# Creating Piano roll: 010506b_: 100%|██████████| 1128/1128 [00:00<00:00, 59376.45it/s]
# Creating Piano roll: 010602b_: 100%|██████████| 1437/1437 [00:00<00:00, 143768.69it/s]
# Creating Piano roll: 010707b_: 100%|██████████| 1212/1212 [00:00<00:00, 242579.52it/s]
# Creating Piano roll: 010806b_: 100%|██████████| 291/291 [00:00<00:00, 96937.69it/s]
# Creating Piano roll: 011007b_: 100%|██████████| 206/206 [00:00<00:00, 68644.37it/s]
# Creating Piano roll: 011106b_: 100%|██████████| 353/353 [00:00<00:00, 117759.43it/s]
# Creating Piano roll: 011205b_: 100%|██████████| 504/504 [00:00<00:00, 91271.07it/s]
# Creating Piano roll: 011308b_: 100%|██████████| 285/285 [00:00<00:00, 142612.34it/s]
# Creating Piano roll: 011407b_: 100%|██████████| 291/291 [00:00<00:00, 146682.19it/s]
# Creating Piano roll: 011506bv: 100%|██████████| 333/333 [00:00<00:00, 333183.02it/s]
# Creating Piano roll: 011506b_: 100%|██████████| 333/333 [00:00<00:00, 103344.67it/s]
# Creating Piano roll: 011606b_: 100%|██████████| 215/215 [00:00<00:00, 215787.36it/s]
# Creating Piano roll: 011704b_: 100%|██████████| 360/360 [00:00<00:00, 120046.86it/s]
# Creating Piano roll: 011704v1: 100%|██████████| 366/366 [00:00<00:00, 91452.12it/s]
# Creating Piano roll: 011704v2: 100%|██████████| 360/360 [00:00<00:00, 120094.60it/s]
# Creating Piano roll: 011909b_: 100%|██████████| 180/180 [00:00<00:00, 42113.83it/s]
# Creating Piano roll: 012006b_: 100%|██████████| 294/294 [00:00<00:00, 73492.19it/s]
# Creating Piano roll: 012008ba: 100%|██████████| 400/400 [00:00<00:00, 133810.94it/s]
# Creating Piano roll: 012106b_: 100%|██████████| 344/344 [00:00<00:00, 114665.86it/s]
# Creating Piano roll: 012206b_: 100%|██████████| 198/198 [00:00<00:00, 56007.03it/s]
# Creating Piano roll: 012306b_: 100%|██████████| 276/276 [00:00<00:00, 92101.83it/s]
# Creating Piano roll: 012406b_: 100%|██████████| 327/327 [00:00<00:00, 81755.93it/s]
# Creating Piano roll: 012506b_: 100%|██████████| 215/215 [00:00<00:00, 214810.71it/s]
# Creating Piano roll: 012606bv: 100%|██████████| 479/479 [00:00<00:00, 95679.19it/s]
# Creating Piano roll: 012606b_: 100%|██████████| 479/479 [00:00<00:00, 119830.11it/s]
# Creating Piano roll: 012705b_: 100%|██████████| 242/242 [00:00<00:00, 48435.85it/s]
# Creating Piano roll: 012805b_: 100%|██████████| 382/382 [00:00<00:00, 191516.15it/s]
# Creating Piano roll: 012905b_: 100%|██████████| 1829/1829 [00:00<00:00, 182860.94it/s]
# Creating Piano roll: 013006b_: 100%|██████████| 391/391 [00:00<00:00, 130363.50it/s]
# Creating Piano roll: 013306b_: 100%|██████████| 237/237 [00:00<00:00, 236847.76it/s]
# Creating Piano roll: 013506b_: 100%|██████████| 276/276 [00:00<00:00, 61195.11it/s]
# Creating Piano roll: 013606b_: 100%|██████████| 338/338 [00:00<00:00, 30728.17it/s]
# Creating Piano roll: 013701b_: 100%|██████████| 4647/4647 [00:00<00:00, 96351.91it/s]
# Creating Piano roll: 013702b_: 100%|██████████| 1304/1304 [00:00<00:00, 118441.08it/s]
# Creating Piano roll: 013703b_: 100%|██████████| 1627/1627 [00:00<00:00, 200409.17it/s]
# Creating Piano roll: 013705b_: 100%|██████████| 400/400 [00:00<00:00, 80017.25it/s]
# Creating Piano roll: 013705ch: 100%|██████████| 206/206 [00:00<00:00, 102823.59it/s]
# Creating Piano roll: 013807b_: 100%|██████████| 1979/1979 [00:00<00:00, 179898.73it/s]
# Creating Piano roll: 013906b_: 100%|██████████| 226/226 [00:00<00:00, 56500.73it/s]
# Creating Piano roll: 014001b_: 100%|██████████| 6068/6068 [00:00<00:00, 93769.94it/s]
# Creating Piano roll: 014004b_: 100%|██████████| 1609/1609 [00:00<00:00, 157630.51it/s]
# Creating Piano roll: 014007b_: 100%|██████████| 405/405 [00:00<00:00, 101239.23it/s]
# Creating Piano roll: 014403b_: 100%|██████████| 270/270 [00:00<00:00, 67480.76it/s]
# Creating Piano roll: 014406b_: 100%|██████████| 334/334 [00:00<00:00, 334422.90it/s]
# Creating Piano roll: 014500ba: 100%|██████████| 213/213 [00:00<00:00, 53142.99it/s]
# Creating Piano roll: 014505bv: 100%|██████████| 175/175 [00:00<00:00, 87370.93it/s]
# Creating Piano roll: 014505b_: 100%|██████████| 176/176 [00:00<00:00, 88006.38it/s]
# Creating Piano roll: 014608b_: 100%|██████████| 287/287 [00:00<00:00, 95628.00it/s]
# Creating Piano roll: 014706b_: 100%|██████████| 1670/1670 [00:00<00:00, 74118.43it/s]
# Creating Piano roll: 014710b_: 100%|██████████| 1670/1670 [00:00<00:00, 95373.11it/s]
# Creating Piano roll: 014806bv: 100%|██████████| 204/204 [00:00<00:00, 102092.59it/s]
# ...
# Creating Piano roll: K546 Adagio & Fugue for Strings: 100%|██████████| 4973/4973 [00:00<00:00, 211146.05it/s]
# Creating Piano roll: K570 Piano Sonata 1mov: 100%|██████████| 2059/2059 [00:00<00:00, 238197.04it/s]
# Creating Piano roll: K570 Piano Sonata 2mov: 100%|██████████| 1826/1826 [00:00<00:00, 261027.20it/s]
# Creating Piano roll: K570 Piano Sonata 3mov: 100%|██████████| 1921/1921 [00:00<00:00, 186553.79it/s]
# Creating Piano roll: K573 9 Variations for Piano Uber Duport: 100%|██████████| 6934/6934 [00:00<00:00, 233007.55it/s]
# Creating Piano roll: K576 Piano Sonata n19 : 100%|██████████| 8001/8001 [00:00<00:00, 214165.27it/s]
# Creating Piano roll: K594 Adagio & Allegro for Mechanical Organ: 100%|██████████| 6000/6000 [00:00<00:00, 217321.45it/s]
# Creating Piano roll: K608 Fantasia for Mechanical Organ: 100%|██████████| 5194/5194 [00:00<00:00, 217856.51it/s]
# Creating Piano roll: K617 Adagio: 100%|██████████| 1244/1244 [00:00<00:00, 196095.69it/s]
# Creating Piano roll: K618 Ave Verum Corpus: 100%|██████████| 451/451 [00:00<00:00, 225866.40it/s]
# Creating Piano roll: K620 Overture The Magic Flute: 100%|██████████| 2683/2683 [00:00<00:00, 235351.20it/s]
# Creating Piano roll: K622 Clarinet Concerto 1mov: 100%|██████████| 9260/9260 [00:00<00:00, 222606.42it/s]
# Creating Piano roll: K622 Clarinet Concerto 2mov: 100%|██████████| 2086/2086 [00:00<00:00, 170124.21it/s]
# Creating Piano roll: K622 Clarinet Concerto 3mov: 100%|██████████| 6929/6929 [00:00<00:00, 237763.70it/s]
# Creating Piano roll: K626 Requiem 01 Introitus & Kyrie: 100%|██████████| 9798/9798 [00:00<00:00, 235789.72it/s]
# Creating Piano roll: K626 Requiem 02 rextremendae: 100%|██████████| 2041/2041 [00:00<00:00, 220360.75it/s]
# Creating Piano roll: K626 Requiem 03 tuba mirum: 100%|██████████| 1361/1361 [00:00<00:00, 186959.94it/s]
# Creating Piano roll: K626 Requiem 04 Dies Irae: 100%|██████████| 5462/5462 [00:00<00:00, 131475.94it/s]
# Creating Piano roll: K626 Requiem 05 Recordare: 100%|██████████| 3535/3535 [00:00<00:00, 218135.16it/s]
# Creating Piano roll: K626 Requiem 06 confutatis: 100%|██████████| 3109/3109 [00:00<00:00, 211463.22it/s]
# Creating Piano roll: K626 Requiem 07 Lacrimosa: 100%|██████████| 2198/2198 [00:00<00:00, 150262.91it/s]
# Creating Piano roll: K626 Requiem 08 offertorio domine jesu: 100%|██████████| 7016/7016 [00:00<00:00, 213803.24it/s]
# Creating Piano roll: K626 Requiem 09 hostias: 100%|██████████| 4736/4736 [00:00<00:00, 205919.43it/s]
# Creating Piano roll: K626 Requiem 10 Sanctus: 100%|██████████| 2044/2044 [00:00<00:00, 243375.84it/s]
# Creating Piano roll: K626 Requiem 11 Benedictus: 100%|██████████| 4112/4112 [00:00<00:00, 210075.37it/s]
# Creating Piano roll: K626 Requiem 12 agnus dei: 100%|██████████| 10696/10696 [00:00<00:00, 181766.26it/s]
# Creating Piano roll: K626 Requiem kyrie: 100%|██████████| 4588/4588 [00:00<00:00, 222424.11it/s]
# Creating Piano roll: Piano Concerto n12 K414 1mov: 100%|██████████| 8541/8541 [00:00<00:00, 233229.28it/s]
# Creating Piano roll: Piano Concerto n12 K414 3mov: 100%|██████████| 5224/5224 [00:00<00:00, 204483.72it/s]
# Creating Piano roll: Piano Concerto n14 K449 1mov: 100%|██████████| 8738/8738 [00:00<00:00, 241091.91it/s]
# Creating Piano roll: Piano Concerto n14 K449 2mov: 100%|██████████| 3153/3153 [00:00<00:00, 236011.00it/s]
# Creating Piano roll: Piano Concerto n14 K449 3mov: 100%|██████████| 6482/6482 [00:00<00:00, 220127.27it/s]
# Creating Piano roll: Piano Concerto n16 K451 1mov: 100%|██████████| 13192/13192 [00:00<00:00, 226732.14it/s]
# Creating Piano roll: Piano Concerto n16 K451 3mov: 100%|██████████| 9228/9228 [00:00<00:00, 237848.20it/s]
# Creating Piano roll: Piano Concerto n17 K453 3mov: 100%|██████████| 10106/10106 [00:00<00:00, 224457.29it/s]
# Creating Piano roll: Piano Concerto n18 K456 1mov ''Paradis'': 100%|██████████| 12487/12487 [00:00<00:00, 209209.22it/s]
# Creating Piano roll: Piano Concerto n18 K456 2mov ''Paradis'': 100%|██████████| 6888/6888 [00:00<00:00, 217654.47it/s]
# Creating Piano roll: Piano Concerto n18 K456 3mov ''Paradis'': 100%|██████████| 9833/9833 [00:00<00:00, 178763.00it/s]
# Creating Piano roll: Piano Concerto n20 K466 1mov: 100%|██████████| 14276/14276 [00:00<00:00, 197848.58it/s]
# Creating Piano roll: Piano Concerto n20 K466 2mov: 100%|██████████| 6222/6222 [00:00<00:00, 217930.50it/s]
# Creating Piano roll: Piano Concerto n20 K466 3mov: 100%|██████████| 9260/9260 [00:00<00:00, 218134.34it/s]
# Creating Piano roll: Piano Concerto n21 K467 1mov ''Elvira Madigan'': 100%|██████████| 16254/16254 [00:00<00:00, 167325.38it/s]
# Creating Piano roll: Piano Concerto n21 K467 2mov ''Elvira Madigan'': 100%|██████████| 5405/5405 [00:00<00:00, 211082.06it/s]
# Creating Piano roll: Piano Concerto n21 K467 3mov ''Elvira Madigan'': 100%|██████████| 8608/8608 [00:00<00:00, 218455.45it/s]
# Creating Piano roll: Piano Concerto n23 K488 1mov: 100%|██████████| 10709/10709 [00:00<00:00, 203476.38it/s]
# Creating Piano roll: Piano Concerto n23 K488 2mov: 100%|██████████| 2595/2595 [00:00<00:00, 216115.38it/s]
# Creating Piano roll: Piano Concerto n23 K488 3mov: 100%|██████████| 11590/11590 [00:00<00:00, 178852.04it/s]
# Creating Piano roll: Piano Concerto n24 K491 1mov: 100%|██████████| 14271/14271 [00:00<00:00, 203355.62it/s]
# Creating Piano roll: Piano Concerto n24 K491 2mov: 100%|██████████| 3973/3973 [00:00<00:00, 170739.14it/s]
# Creating Piano roll: Piano Concerto n24 K491 3mov: 100%|██████████| 8880/8880 [00:00<00:00, 157788.82it/s]
# Creating Piano roll: Piano Concerto n25 K503 1mov: 100%|██████████| 14431/14431 [00:00<00:00, 112877.78it/s]
# Creating Piano roll: Piano Concerto n25 K503 2mov: 100%|██████████| 3392/3392 [00:00<00:00, 76039.57it/s]
# Creating Piano roll: Piano Concerto n25 K503 3mov: 100%|██████████| 9137/9137 [00:00<00:00, 136638.79it/s]
# Creating Piano roll: Piano Concerto n26 K537 1mov ''Coronation'': 100%|██████████| 13206/13206 [00:00<00:00, 154342.51it/s]
# Creating Piano roll: Piano Concerto n26 K537 2mov ''Coronation'': 100%|██████████| 3079/3079 [00:00<00:00, 133855.68it/s]
# Creating Piano roll: Piano Concerto n26 K537 3mov ''Coronation'': 100%|██████████| 11037/11037 [00:00<00:00, 150122.04it/s]
# Creating Piano roll: Piano Concerto n6 K238 1mov: 100%|██████████| 6489/6489 [00:00<00:00, 63914.35it/s]
# Creating Piano roll: Piano Concerto n6 K238 3mov: 100%|██████████| 7222/7222 [00:00<00:00, 124494.54it/s]
# Creating Piano roll: Piano Concerto n7 for 3 Pianos K242 1mov ''Lodron'': 100%|██████████| 10280/10280 [00:00<00:00, 183458.97it/s]
# Creating Piano roll: Piano Concerto n7 for 3 Pianos K242 2mov ''Lodron'': 100%|██████████| 6299/6299 [00:00<00:00, 182406.37it/s]
# Creating Piano roll: Piano Concerto n7 for 3 Pianos K242 3mov ''Lodron'': 100%|██████████| 5616/5616 [00:00<00:00, 224671.28it/s]
# Creating Piano roll: Piano Concerto n8 K246 1mov: 100%|██████████| 7225/7225 [00:00<00:00, 187968.13it/s]
# Creating Piano roll: Piano Concerto n8 K246 3mov: 100%|██████████| 6165/6165 [00:00<00:00, 205164.31it/s]
# Creating Piano roll: Piano Sonata n01 K279: 100%|██████████| 5567/5567 [00:00<00:00, 186851.34it/s]
# Creating Piano roll: Piano Sonata n02 K280: 100%|██████████| 4774/4774 [00:00<00:00, 120566.76it/s]
# Creating Piano roll: Piano Sonata n03 K281: 100%|██████████| 5855/5855 [00:00<00:00, 204133.35it/s]
# Creating Piano roll: Piano Sonata n04 K282: 100%|██████████| 3257/3257 [00:00<00:00, 245301.64it/s]
# Creating Piano roll: Piano Sonata n05 K283: 100%|██████████| 4815/4815 [00:00<00:00, 85339.78it/s]
# Creating Piano roll: Piano Sonata n06 K284: 100%|██████████| 10585/10585 [00:00<00:00, 121302.48it/s]
# Creating Piano roll: Piano Sonata n07 K309: 100%|██████████| 7577/7577 [00:00<00:00, 110177.06it/s]
# Creating Piano roll: Piano Sonata n08 K311: 100%|██████████| 7157/7157 [00:00<00:00, 107143.59it/s]
# Creating Piano roll: Piano Sonata n09 K310: 100%|██████████| 8117/8117 [00:00<00:00, 143773.03it/s]
# Creating Piano roll: Piano Sonata n10 K330: 100%|██████████| 5770/5770 [00:00<00:00, 111896.72it/s]
# Creating Piano roll: Piano Sonata n11 K331: 100%|██████████| 9470/9470 [00:00<00:00, 108766.06it/s]
# Creating Piano roll: Piano Sonata n12 K332: 100%|██████████| 6868/6868 [00:00<00:00, 97583.59it/s]
# Creating Piano roll: Piano Sonata n13 K333: 100%|██████████| 7496/7496 [00:00<00:00, 211198.61it/s]
# Creating Piano roll: Piano Sonata n14 K457: 100%|██████████| 6400/6400 [00:00<00:00, 212339.58it/s]
# Creating Piano roll: Piano Sonata n15 K593-494: 100%|██████████| 7583/7583 [00:00<00:00, 173028.50it/s]
# Creating Piano roll: Piano Sonata n16 K545: 100%|██████████| 3628/3628 [00:00<00:00, 222063.99it/s]
# Creating Piano roll: Piano Sonata n17 K547a: 100%|██████████| 3441/3441 [00:00<00:00, 236386.87it/s]
# Creating Piano roll: Piano Sonata n18 K570: 100%|██████████| 5917/5917 [00:00<00:00, 191872.10it/s]
# Creating Piano roll: Piano Sonata n19 K576: 100%|██████████| 5920/5920 [00:00<00:00, 215342.48it/s]
# Creating Piano roll: Rondo in C: 100%|██████████| 2681/2681 [00:00<00:00, 237655.95it/s]
# Creating Piano roll: Rondo: 100%|██████████| 4922/4922 [00:00<00:00, 222218.97it/s]
# Creating Piano roll: Sonatina n21 3mov: 100%|██████████| 996/996 [00:00<00:00, 189431.22it/s]
# Creating Piano roll: Sonatina n22 4mov: 100%|██████████| 873/873 [00:00<00:00, 218369.95it/s]
# Creating Piano roll: Sonatina n3 1mov: 100%|██████████| 498/498 [00:00<00:00, 124598.15it/s]
# Creating Piano roll: Sonatina n3 2mov: 100%|██████████| 1284/1284 [00:00<00:00, 142661.89it/s]
# Creating Piano roll: Sonatina n3 3mov: 100%|██████████| 1431/1431 [00:00<00:00, 178909.29it/s]
# Creating Piano roll: Symphony n22 K162 1mov: 100%|██████████| 4651/4651 [00:00<00:00, 215371.54it/s]
# Creating Piano roll: Symphony n22 K162 3mov: 100%|██████████| 3979/3979 [00:00<00:00, 79559.59it/s]
# Creating Piano roll: Symphony n25 K183 1mov: 100%|██████████| 11852/11852 [00:00<00:00, 218913.56it/s]
# Creating Piano roll: Symphony n25 K183 2mov: 100%|██████████| 1905/1905 [00:00<00:00, 206075.08it/s]
# Creating Piano roll: Symphony n25 K183 3mov: 100%|██████████| 3035/3035 [00:00<00:00, 216819.89it/s]
# Creating Piano roll: Symphony n25 K183 4mov: 100%|██████████| 7533/7533 [00:00<00:00, 224453.83it/s]
# Creating Piano roll: Symphony n28 K200 1mov: 100%|██████████| 7164/7164 [00:00<00:00, 189363.39it/s]
# Creating Piano roll: Symphony n28 K200 2mov: 100%|██████████| 2381/2381 [00:00<00:00, 193772.32it/s]
# Creating Piano roll: Symphony n28 K200 3mov: 100%|██████████| 2741/2741 [00:00<00:00, 195643.30it/s]
# Creating Piano roll: Symphony n28 K200 4mov: 100%|██████████| 6899/6899 [00:00<00:00, 230008.93it/s]
# Creating Piano roll: Symphony n29 K201 1mov: 100%|██████████| 8056/8056 [00:00<00:00, 217673.97it/s]
# Creating Piano roll: Symphony n29 K201 2mov: 100%|██████████| 3571/3571 [00:00<00:00, 233067.65it/s]
# Creating Piano roll: Symphony n29 K201 4mov: 100%|██████████| 8130/8130 [00:00<00:00, 222636.61it/s]
# Creating Piano roll: Symphony n30 K202 1mov: 100%|██████████| 7650/7650 [00:00<00:00, 198598.86it/s]
# Creating Piano roll: Symphony n30 K202 2mov: 100%|██████████| 1821/1821 [00:00<00:00, 147745.04it/s]
# Creating Piano roll: Symphony n30 K202 3mov: 100%|██████████| 3597/3597 [00:00<00:00, 179852.32it/s]
# Creating Piano roll: Symphony n30 K202 4mov: 100%|██████████| 4857/4857 [00:00<00:00, 140358.23it/s]
# Creating Piano roll: Symphony n31 K297 1mov ''Paris'': 100%|██████████| 13940/13940 [00:00<00:00, 209389.25it/s]
# Creating Piano roll: Symphony n31 K297 2mov ''Paris'': 100%|██████████| 2958/2958 [00:00<00:00, 219138.60it/s]
# Creating Piano roll: Symphony n31 K297 3mov ''Paris'': 100%|██████████| 7440/7440 [00:00<00:00, 223419.14it/s]
# Creating Piano roll: Symphony n33 K319 1mov: 100%|██████████| 8125/8125 [00:00<00:00, 221849.33it/s]
# Creating Piano roll: Symphony n33 K319 2mov: 100%|██████████| 2328/2328 [00:00<00:00, 135455.92it/s]
# Creating Piano roll: Symphony n33 K319 3mov: 100%|██████████| 2344/2344 [00:00<00:00, 228097.27it/s]
# Creating Piano roll: Symphony n33 K319 4mov: 100%|██████████| 9710/9710 [00:00<00:00, 135923.73it/s]
# Creating Piano roll: Symphony n34 K338 1mov: 100%|██████████| 11066/11066 [00:00<00:00, 222994.95it/s]
# Creating Piano roll: Symphony n34 K338 2mov: 100%|██████████| 3090/3090 [00:00<00:00, 168856.34it/s]
# Creating Piano roll: Symphony n34 K338 3mov: 100%|██████████| 11411/11411 [00:00<00:00, 161243.30it/s]
# Creating Piano roll: Symphony n35 K385 1mov ''Haffner'': 100%|██████████| 10611/10611 [00:00<00:00, 161252.17it/s]
# Creating Piano roll: Symphony n35 K385 2mov ''Haffner'': 100%|██████████| 6050/6050 [00:00<00:00, 181855.27it/s]
# Creating Piano roll: Symphony n35 K385 3mov ''Haffner'': 100%|██████████| 3416/3416 [00:00<00:00, 213372.39it/s]
# Creating Piano roll: Symphony n35 K385 4mov ''Haffner'': 100%|██████████| 10103/10103 [00:00<00:00, 198354.44it/s]
# Creating Piano roll: Symphony n36 K425 1mov ''Linz'': 100%|██████████| 17850/17850 [00:00<00:00, 165176.35it/s]
# Creating Piano roll: Symphony n36 K425 2mov ''Linz'': 100%|██████████| 4180/4180 [00:00<00:00, 217580.37it/s]
# Creating Piano roll: Symphony n36 K425 3mov ''Linz'': 100%|██████████| 3326/3326 [00:00<00:00, 211409.14it/s]
# Creating Piano roll: Symphony n36 K425 4mov ''Linz'': 100%|██████████| 12551/12551 [00:00<00:00, 152069.65it/s]
# Creating Piano roll: Symphony n37 K444 1mov: 100%|██████████| 608/608 [00:00<00:00, 99919.16it/s]
# Creating Piano roll: Symphony n38 K504 1mov ''Prague'': 100%|██████████| 16747/16747 [00:00<00:00, 227601.05it/s]
# Creating Piano roll: Symphony n38 K504 2mov ''Prague'': 100%|██████████| 6671/6671 [00:00<00:00, 209485.96it/s]
# Creating Piano roll: Symphony n38 K504 3mov ''Prague'': 100%|██████████| 7876/7876 [00:00<00:00, 231397.72it/s]
# Creating Piano roll: Symphony n39 K543 1mov: 100%|██████████| 16108/16108 [00:00<00:00, 223474.98it/s]
# Creating Piano roll: Symphony n39 K543 2mov: 100%|██████████| 4829/4829 [00:00<00:00, 218114.11it/s]
# Creating Piano roll: Symphony n39 K543 3mov: 100%|██████████| 5218/5218 [00:00<00:00, 239273.61it/s]
# Creating Piano roll: Symphony n39 K543 4mov: 100%|██████████| 12775/12775 [00:00<00:00, 232819.46it/s]
# Creating Piano roll: Symphony n4 K019 1mov: 100%|██████████| 6528/6528 [00:00<00:00, 224764.95it/s]
# Creating Piano roll: Symphony n4 K19 3mov: 100%|██████████| 3357/3357 [00:00<00:00, 235404.99it/s]
# Creating Piano roll: Symphony n40 K550 1mov: 100%|██████████| 12699/12699 [00:00<00:00, 226932.13it/s]
# Creating Piano roll: Symphony n40 K550 2mov: 100%|██████████| 3934/3934 [00:00<00:00, 209715.20it/s]
# Creating Piano roll: Symphony n40 K550 3mov: 100%|██████████| 4173/4173 [00:00<00:00, 102864.64it/s]
# Creating Piano roll: Symphony n40 K550 4mov: 100%|██████████| 11260/11260 [00:00<00:00, 205619.25it/s]
# Creating Piano roll: Symphony n41 K551 1mov ''Jupiter'': 100%|██████████| 16974/16974 [00:00<00:00, 161019.11it/s]
# Creating Piano roll: Symphony n41 K551 2mov ''Jupiter'': 100%|██████████| 5082/5082 [00:00<00:00, 156429.91it/s]
# Creating Piano roll: Symphony n41 K551 3mov ''Jupiter'': 100%|██████████| 2562/2562 [00:00<00:00, 227984.19it/s]
# Creating Piano roll: Symphony n41 K551 4mov ''Jupiter'': 100%|██████████| 17350/17350 [00:00<00:00, 192139.68it/s]
# Creating Piano roll: Symphony n5 K022: 100%|██████████| 7916/7916 [00:00<00:00, 235164.08it/s]
# Creating Piano roll: Vesperae solemnes de confessore ''Vespers'' K339 1 Dixit Dominus: 100%|██████████| 5863/5863 [00:00<00:00, 233434.95it/s]
# Creating Piano roll: Viennese Sonatinas K439b n2 1mov: 100%|██████████| 996/996 [00:00<00:00, 196183.28it/s]
# Creating Piano roll: Viennese Sonatinas K439b n2 2mov: 100%|██████████| 873/873 [00:00<00:00, 173528.62it/s]
# Creating Piano roll: Viennese Sonatinas K439b n2 3mov: 100%|██████████| 573/573 [00:00<00:00, 191089.78it/s]
# Creating Piano roll: Viennese Sonatinas K439b n2 4mov: 100%|██████████| 1814/1814 [00:00<00:00, 226631.34it/s]
# Creating Piano roll: Viennese Sonatinas K439b n6 1mov: 100%|██████████| 2190/2190 [00:00<00:00, 191724.60it/s]
# Creating Piano roll: Viennese Sonatinas K439b n6 2mov: 100%|██████████| 999/999 [00:00<00:00, 121041.96it/s]

# %%
index = 3
fig = plt.figure(figsize=(18, 4))
fig.suptitle(f"Piano roll for composer: {list_composer_names[index]} --> song: {list_song_names[index]}")
fig.subplots_adjust(top = 0.8)
ax1 = fig.add_subplot(1, 1, 1)
ax1.imshow(list_np_arrays[index], label = list_composer_names[index])
ax1.axis("off")
plt.show()

for i, np_array in enumerate(list_np_arrays[0:10]):
    print(f"Piano roll for composer: {list_composer_names[i]} --> song: {list_song_names[i]}: shape is {np_array.shape}")
print(np.unique(list_composer_names))
# Out:
# Piano roll for composer: Bach_0 --> song: (2542)Prelude opus.28, No.16 in B flat minor: shape is (128, 630)
# Piano roll for composer: Bach_1 --> song: 19 Polish Songs, for Solo Voice and Piano accomplements, No.10: shape is (128, 780)
# Piano roll for composer: Bach_2 --> song: 19 Polish Songs, for Solo Voice and Piano accomplements, No.11: shape is (128, 600)
# Piano roll for composer: Bach_3 --> song: 19 Polish Songs, for Solo Voice and Piano accomplements, No.12: shape is (128, 1140)
# Piano roll for composer: Bach_4 --> song: 19 Polish Songs, for Solo Voice and Piano accomplements, No.13: shape is (128, 2290)
# Piano roll for composer: Bach_5 --> song: 19 Polish Songs, for Solo Voice and Piano accomplements, No.14: shape is (128, 850)
# Piano roll for composer: Bach_6 --> song: 19 Polish Songs, for Solo Voice and Piano accomplements, No.15: shape is (128, 1540)
# Piano roll for composer: Bach_7 --> song: 19 Polish Songs, for Solo Voice and Piano accomplements, No.16: shape is (128, 1140)
# Piano roll for composer: Bach_8 --> song: 19 Polish Songs, for Solo Voice and Piano accomplements, No.17: shape is (128, 2360)
# Piano roll for composer: Bach_9 --> song: 19 Polish Songs, for Solo Voice and Piano accomplements, No.18: shape is (128, 2930)
# ['Bach_0' 'Bach_1' 'Bach_10' ... 'Mozart_97' 'Mozart_98' 'Mozart_99']

# %% [markdown]
# ### NICE!
# Lets create a function that pads them properly!
# - Now, this is gonna be difficult, first we need to take a look into the list of np_arrays and see the distribution of the time lengths.
# - Looking at the distribution, select a default time . Remember, we used `fs = 10`, which means we can see the time distributions with `np_array.shape[1]/fs`.
# - Once we have that, we can create a class that would pad ALL of the np_arrays properly by using `torch.tensor.repeat` along axis = 1 -> `shape = (128, T)`
# - **MAINTAIN NP ARRAY ORDER**, So when we start oversampling and undersampling, we are able to have proper labels vs piano roll images.

# %%
discrete_lengths = []
time_lenghts = []
fs = 10
for i in range(len(list_np_arrays)):
    len_array = list_np_arrays[i].shape[1]
    discrete_lengths.append(len_array)
    time_lenghts.append(len_array/fs)

fig = plt.figure(figsize=(18, 8))
fig.suptitle(f"Piano roll histogram for all piano rolls")
fig.subplots_adjust(top = 0.8)
ax1 = fig.add_subplot(2, 1, 1)
ax1.hist(discrete_lengths, edgecolor = "black", bins=100)
ax1.set_xlabel("Discrete samples [n]")
print(np.median(discrete_lengths))

ax2 = fig.add_subplot(2, 1, 2)
ax2.hist(time_lenghts, edgecolor = "black",  bins=100)
ax2.set_xlabel("Time seconds (t) = discrete_samples / fs")
print(np.median(time_lenghts))
# Out:
# 1565.0
# 156.5

# %% [markdown]
# The observations of the lengths of different time songs show that its skewed to the left, meaning that we would like to select a right size like this:
# - If the song has more than the `np.median` of lengths, then select like this `ndarray[:, :np.median(lengths))]`.
# - If song has less than the median of lengths do the following:
#     - set `max_len_array = np.median(lengths)`
#     - calculate `repeats = (max_len_array // ndarray.shape[1]) + 1`
#     - tiled is `tensor.repeat(1, repeats)`
#     - check if `tiled.shape[1] >= max_len_array`, if it is, then `tiled[:, :max_len_array]`, else: repeat again with tile until you select `tiled[:, :max_len_array]`

# %%
import torch
import torch.nn.functional as F

max_len_array = 0
for i in range(len(list_np_arrays)):
    len_array = list_np_arrays[i].shape[1]
    if len_array > max_len_array:
        max_len_array = len_array
print(max_len_array/10)

index = 0
tensor = torch.tensor(list_np_arrays[index])  # Shape: [128, T]
repeats = (max_len_array // tensor.shape[1]) + 1
tiled = tensor.repeat(1, repeats)  # Repeat along time axis
padded_tensor = tiled[:, :max_len_array]  # Trim to target size

print(tensor.shape)
print(padded_tensor.shape)

index = i
fig = plt.figure(figsize=(18, 8))
fig.suptitle(f"Piano roll for composer: {list_composer_names[index]} --> song: {list_song_names[index]}")
fig.subplots_adjust(top = 0.8)
ax1 = fig.add_subplot(3, 1, 1)
ax1.imshow(tensor, label = list_composer_names[index])
ax1.axis("off")

ax2 = fig.add_subplot(3, 1, 2)
ax2.imshow(padded_tensor[:, 0:2*tensor.shape[1]], label = list_composer_names[index])
ax2.axis("off")

ax3 = fig.add_subplot(3, 1, 3)
ax3.imshow(padded_tensor[:, 0:int(np.median(discrete_lengths))], label = list_composer_names[index])
ax3.axis("off")

plt.show()
# Out:
# 10693.0
# torch.Size([128, 630])
# torch.Size([128, 106930])

# %%
class PianoRollsDiscreteEqualizer:
    '''
    Class that woild take a list of np.ndarrays of size
    (128, T). Where T is a varying number of discrete samples
    per piano roll.

    Args:
        - piano_rolls: List of np.ndarrays of size (128, T), with varying Ts
    
    Returns:
        - equalized_piano_rolls: np.ndarray of shape (N, 128, Teq)
    
    Example:
        equalizer = PianoRollsDiscreteEqualizer(piano_rolls = previous_pianos)
        eq_piano_rolls = equalizer.get_equalized()
    '''

    def __init__(self, piano_rolls: List[np.ndarray]) -> None:
        self.piano_rolls = piano_rolls
        self.piano_median = None
        self.piano_diff_lengths = []
    
    def _calculate_median_various_lengths(self) -> None:
        for nparray in self.piano_rolls:
            self.piano_diff_lengths.append(nparray.shape[1])
        self.piano_median = int(np.median(self.piano_diff_lengths))
    
    def get_equalized(self) -> np.ndarray[int]:
        self._calculate_median_various_lengths()
        equalized_np_arrays = []
        for nparray in tqdm(self.piano_rolls, desc="Equalizing piano rolls...", total=len(self.piano_rolls)):
            if len(nparray) >= self.piano_median:
                equalized_np_arrays.append(nparray[:, :self.piano_median])
            else:
                tiled = nparray
                while tiled.shape[1] < self.piano_median:
                    repeats = int((self.piano_median // tiled.shape[1]) + 1)
                    tiled = np.tile(tiled, repeats)  # Repeat along time axis
                equalized_np_arrays.append(tiled[:, :self.piano_median])

        return np.array(equalized_np_arrays, dtype=np.int64)

# %%
equalizer = PianoRollsDiscreteEqualizer(piano_rolls = list_np_arrays)
eq_piano_rolls = equalizer.get_equalized()
print(eq_piano_rolls.shape)
# Out:
# Equalizing piano rolls...: 100%|██████████| 1528/1528 [00:00<00:00, 3603.57it/s]
# (1528, 128, 1565)

# %%
index = 10
fig = plt.figure(figsize=(16, 8))
fig.suptitle(f"Piano roll for composer: {list_composer_names[index]} --> song: {list_song_names[index]} and properly padded version")
fig.subplots_adjust(top = 0.8)
ax1 = fig.add_subplot(2, 1, 1)
ax1.imshow(list_np_arrays[index], label = list_composer_names[index])
ax1.axis("off")

ax2 = fig.add_subplot(2, 1, 2)
ax2.imshow(eq_piano_rolls[index], label = list_composer_names[index])
ax2.axis("off")

plt.show()
